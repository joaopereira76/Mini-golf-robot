# %%
import cv2

cap = cv2.VideoCapture('http://192.168.1.77:8080/video')

while(True):
    ret, frame = cap.read()
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break

# %%
import cv2
import numpy as np

def detect_robot_and_ball(frame):
   
    # Convert the image to HSV color space
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Define color ranges for the ball (green) and robot (white)
    green_lower = (35, 50, 50)    # Adjust based on your green ball's actual color
    green_upper = (85, 255, 255)  # Adjust based on your green ball's actual color


    # Threshold the image to get masks for green and white
    ball_mask = cv2.inRange(hsv, green_lower, green_upper)


    # Find contours for the ball and robot
    ball_contours, _ = cv2.findContours(ball_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Initialize centroids as None
    ball_centroid = None

    # Find the largest contour for the ball (assuming it's the most significant green object)
    if ball_contours:
        ball_contour = max(ball_contours, key=cv2.contourArea)
        ball_moments = cv2.moments(ball_contour)
        if ball_moments['m00'] != 0:  # Avoid division by zero
            ball_centroid = (int(ball_moments['m10'] / ball_moments['m00']),
                             int(ball_moments['m01'] / ball_moments['m00']))

    return ball_centroid

# Main script
if __name__ == "__main__":
    # Open the camera feed (adjust the index for your camera)
    cap = cv2.VideoCapture('http://192.168.1.77:8080/video')

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Resize the frame for easier processing (optional)
        frame = cv2.resize(frame, (640, 480))

        # Detect the robot and ball
        robot_pos, ball_pos = detect_robot_and_ball(frame)

        # Draw the detected positions on the frame
        if ball_pos:
            cv2.circle(frame, ball_pos, 10, (0, 255, 0), -1)  # Green dot for the ball
            cv2.putText(frame, "Ball", ball_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Display the frame with annotations
        cv2.imshow("Frame", frame)

        # Break the loop with 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release resources
    cap.release()
    cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

def detect_objects(frame):
    """
    Detects the white robot, green ball, and blue ball in a frame.

    Args:
        frame: The input image from the camera.

    Returns:
        robot_centroid: (x, y) coordinates of the robot's center or None if not found.
        green_ball_centroid: (x, y) coordinates of the green ball's center or None if not found.
        blue_ball_centroid: (x, y) coordinates of the blue ball's center or None if not found.
    """
    # Convert the image to HSV color space
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Define color ranges for green, blue, and white
    green_lower = (35, 50, 50)    # Adjust based on your green ball's actual color
    green_upper = (85, 255, 255)  # Adjust based on your green ball's actual color

    blue_lower = (100, 50, 50)    # Adjust based on your blue ball's actual color
    blue_upper = (140, 255, 255)  # Adjust based on your blue ball's actual color

    white_lower = (0, 0, 200)     # White detection (high saturation for clarity)
    white_upper = (180, 55, 255)  # Fine-tune based on lighting

    # Threshold the image to get masks for green, blue, and white
    green_mask = cv2.inRange(hsv, green_lower, green_upper)
    blue_mask = cv2.inRange(hsv, blue_lower, blue_upper)
    robot_mask = cv2.inRange(hsv, white_lower, white_upper)

    # Find contours for each object
    green_contours, _ = cv2.findContours(green_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    blue_contours, _ = cv2.findContours(blue_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    robot_contours, _ = cv2.findContours(robot_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Initialize centroids as None
    green_ball_centroid = None
    blue_ball_centroid = None
    robot_centroid = None

    # Find the largest contour for the green ball
    if green_contours:
        green_contour = max(green_contours, key=cv2.contourArea)
        green_moments = cv2.moments(green_contour)
        if green_moments['m00'] != 0:  # Avoid division by zero
            green_ball_centroid = (int(green_moments['m10'] / green_moments['m00']),
                                   int(green_moments['m01'] / green_moments['m00']))

    # Find the largest contour for the blue ball
    if blue_contours:
        blue_contour = max(blue_contours, key=cv2.contourArea)
        blue_moments = cv2.moments(blue_contour)
        if blue_moments['m00'] != 0:  # Avoid division by zero
            blue_ball_centroid = (int(blue_moments['m10'] / blue_moments['m00']),
                                  int(blue_moments['m01'] / blue_moments['m00']))

    # Find the largest contour for the robot
    if robot_contours:
        robot_contour = max(robot_contours, key=cv2.contourArea)
        robot_moments = cv2.moments(robot_contour)
        if robot_moments['m00'] != 0:  # Avoid division by zero
            robot_centroid = (int(robot_moments['m10'] / robot_moments['m00']),
                              int(robot_moments['m01'] / robot_moments['m00']))

    return robot_centroid, green_ball_centroid, blue_ball_centroid

# Main script
if __name__ == "__main__":
    # Open the camera feed (adjust the index for your camera)
    cap = cv2.VideoCapture('http://192.168.1.77:8080/video')

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Resize the frame for easier processing (optional)
        frame = cv2.resize(frame, (640, 480))

        # Detect the robot, green ball, and blue ball
        robot_pos, green_ball_pos, blue_ball_pos = detect_objects(frame)

        # Draw the detected positions on the frame
        if green_ball_pos:
            cv2.circle(frame, green_ball_pos, 10, (0, 255, 0), -1)  # Green dot for the green ball
            cv2.putText(frame, "Green Ball", green_ball_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        if blue_ball_pos:
            cv2.circle(frame, blue_ball_pos, 10, (255, 0, 0), -1)  # Blue dot for the blue ball
            cv2.putText(frame, "Blue Ball", blue_ball_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
        if robot_pos:
            cv2.circle(frame, robot_pos, 10, (255, 255, 255), -1)  # White dot for the robot
            cv2.putText(frame, "Robot", robot_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

        # Display the frame with annotations
        cv2.imshow("Frame", frame)

        # Break the loop with 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release resources
    cap.release()
    cv2.destroyAllWindows()

# %%
import cv2
import cv2.aruco as aruco

# Specify the dictionary and ID of the marker
dictionary = aruco.getPredefinedDictionary(aruco.DICT_4X4_50)
marker_id = 0  # ID of the marker
marker_size = 200  # Size in pixels

# Create the marker
marker = aruco.generateImageMarker(dictionary, marker_id, marker_size)

# Save the marker as an image
cv2.imwrite("marker.png", marker)
cv2.imshow("Marker", marker)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the ArUco dictionary
dictionary = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_50)

# Initialize the parameters for marker detection
parameters = cv2.aruco.DetectorParameters()

# Open the video feed (0 is the default camera, change if you use another camera)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open video feed.")
    exit()

while True:
    # Capture a frame from the video feed
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    # Detect markers in the frame
    corners, ids, rejected = cv2.aruco.detectMarkers(frame, dictionary, parameters=parameters)

    # If markers are detected
    if ids is not None:
        # Draw detected markers and their IDs
        frame = cv2.aruco.drawDetectedMarkers(frame, corners, ids)
        
        # Example: Print marker IDs
        print("Detected markers:", ids.flatten())

    # Display the video feed with the detected markers
    cv2.imshow("ArUco Marker Detection", frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]
# Detected markers: [0]

# %%
import cv2
import numpy as np

# Known parameters
real_marker_width = 7  # Real marker width in meters (e.g., 10 cm = 0.1 m)

# Camera calibration: use focal length in pixels (you can get this from calibration)
focal_length = 500  # Example value, replace with your camera's focal length (in pixels)

# Load the ArUco dictionary and detector parameters
dictionary = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_50)
parameters = cv2.aruco.DetectorParameters()

# Open the video feed
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open video feed.")
    exit()

while True:
    # Capture a frame from the video feed
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    # Detect markers in the frame
    corners, ids, rejected = cv2.aruco.detectMarkers(frame, dictionary, parameters=parameters)

    # If markers are detected
    if ids is not None:
        for i in range(len(ids)):
            # Get the width of the marker in pixels (e.g., from the first corner)
            marker_width_pixels = np.linalg.norm(corners[i][0][0] - corners[i][0][1])  # Horizontal width in pixels

            # Estimate the distance (D) to the marker
            distance = (focal_length * real_marker_width) / marker_width_pixels

            # Draw the detected marker and display the distance
            cv2.aruco.drawDetectedMarkers(frame, corners, ids)
            cv2.putText(frame, f"Distance: {distance:.2f} cent", 
                        (int(corners[i][0][0][0]), int(corners[i][0][0][1]-10)), 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Display the frame with the marker and distance info
    cv2.imshow("ArUco Marker Detection", frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
import os
import glob

# Termination criteria for corner refinement
criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# Prepare object points (real-world coordinates for the chessboard)
chessboard_size = (7, 6)  # Number of inner corners per row and column
square_size = 1.0  # Size of a square in your desired units (e.g., 1.0 for 1 meter or 1 centimeter)
objp = np.zeros((chessboard_size[0] * chessboard_size[1], 3), np.float32)
objp[:, :2] = np.mgrid[0:chessboard_size[0], 0:chessboard_size[1]].T.reshape(-1, 2) * square_size

# Arrays to store object points and image points
objpoints = []  # 3D points in real-world space
imgpoints = []  # 2D points in image plane

# Folder containing calibration images
image_folder = "./calibration"

# Get all image paths
images = glob.glob(os.path.join(image_folder, "*.jpeg"))  # Adjust the extension if necessary

if not images:
    print("No images found in the specified folder.")
    exit()

# Process each image
for fname in images:
    img = cv.imread(fname)
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

    # Find the chessboard corners
    ret, corners = cv.findChessboardCorners(gray, chessboard_size, None)

    if ret:
        objpoints.append(objp)
        corners2 = cv.cornerSubPix(gray, corners, (11, 11), (-1, -1), criteria)
        imgpoints.append(corners2)

        # Optionally, draw and display the corners
        cv.drawChessboardCorners(img, chessboard_size, corners2, ret)
        cv.imshow('Chessboard Corners', img)
        cv.waitKey(500)

cv.destroyAllWindows()

# Perform calibration if sufficient data is collected
if len(objpoints) > 0:
    ret, mtx, dist, rvecs, tvecs = cv.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)

    if ret:
        print("Camera calibration successful.")
        print("Camera matrix:\n", mtx)
        print("Distortion coefficients:\n", dist)

        # Save the calibration results for later use
        np.savez("calibration_data.npz", camera_matrix=mtx, distortion_coefficients=dist)
    else:
        print("Camera calibration failed.")
else:
    print("Not enough valid chessboard images for calibration.")
# Out:
# Camera calibration successful.
# Camera matrix:
#  [[1.50733727e+03 0.00000000e+00 1.00216430e+03]
#  [0.00000000e+00 1.60351037e+03 5.73667724e+02]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
# Distortion coefficients:
#  [[ 4.93546538e-01 -2.83053197e+00 -4.86613184e-03  8.99750582e-03
#    4.93028537e+00]]

# %%
#import tdmclient.notebook
#await tdmclient.notebook.start()
import math
import time
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Separate 2D world plotting setup
def setup_2d_world():
    global fig_2d, ax_2d, robot_dot, ball_dot, goal_dot, robot_arrow

    plt.ion()  # Turn on interactive mode
    fig_2d, ax_2d = plt.subplots()
    robot_dot, = ax_2d.plot([], [], 'bo', label='Robot')  # Blue dot for robot
    ball_dot, = ax_2d.plot([], [], 'go', label='Ball')  # Green dot for ball
    goal_dot, = ax_2d.plot([], [], 'ro', label='Goal')  # Red dot for goal
    robot_arrow = ax_2d.quiver([], [], [], [], angles='xy', scale_units='xy', scale=1, color='blue')

    ax_2d.set_xlim(-10, 10)
    ax_2d.set_ylim(-10, 10)
    ax_2d.set_xlabel('X')
    ax_2d.set_ylabel('Y')
    ax_2d.legend()
    ax_2d.set_title('2D Environment')

    plt.show()

def update_2d_env(tvec, rvec, ball_pos):
    """Update the 2D environment with the latest positions."""
    if tvec is not None:
        # Robot position
        robot_pos = tvec.flatten()[:2]  # X, Y coordinates from tvec
        robot_dot.set_data([robot_pos[0]], [robot_pos[1]])

        # Robot orientation (arrow pointing forward)
        rotation_matrix, _ = cv.Rodrigues(rvec)
        robot_forward = rotation_matrix[:2, 2]  # Z-axis in marker frame (X, Y projection)
        robot_arrow.set_offsets(robot_pos)
        robot_arrow.set_UVC(robot_forward[0], robot_forward[1])

    print("ball_pos:" + str(ball_pos))
    
    if ball_pos:
        # Ball position (convert to world coordinates if necessary)
        ball_x, ball_y = ball_pos
        ball_dot.set_data([ball_x], [ball_y])  # Correctly update ball position

    # Clear any stale visuals and redraw the plot
    ax_2d.relim()  # Recompute limits based on the new data
    ax_2d.autoscale_view()
    fig_2d.canvas.draw()
    fig_2d.canvas.flush_events()


# Call the setup function before starting the main loop
setup_2d_world()



def image_to_world(ball_pos, marker_tvec, marker_rvec, z_plane=0):
    print(f"Input ball_pos: {ball_pos}, marker_tvec: {marker_tvec}, marker_rvec: {marker_rvec}")

    ball_ray_camera = np.array([ball_pos[0], ball_pos[1], 1.0])  # Assume undistorted points
    rotation_matrix, _ = cv.Rodrigues(marker_rvec)

    # Transform ball ray to marker frame
    ball_ray_marker = np.dot(rotation_matrix.T, ball_ray_camera - marker_tvec.flatten())

    # Handle near-zero Z value to avoid divide-by-zero errors
    if abs(ball_ray_marker[2]) < 1e-6:
        print("Error: Z value in ball_ray_marker is near zero, skipping projection.")
        return None

    # Project to the Z-plane in marker's frame
    scale = (z_plane - marker_tvec[2]) / ball_ray_marker[2]
    ball_marker = scale * ball_ray_marker[:2]

    # Calculate world position
    world_position = tuple(marker_tvec[:2] + ball_marker)
    print(f"Calculated world position: {world_position}")

    return world_position




###################################################################


marker_length = 0.07 

def rotation_matrix_to_euler_angles(R):
    sy = math.sqrt(R[0, 0] * R[0, 0] + R[1, 0] * R[1, 0])

    singular = sy < 1e-6

    if not singular:
        x = math.atan2(R[2, 1], R[2, 2])
        y = math.atan2(-R[2, 0], sy)
        z = math.atan2(R[1, 0], R[0, 0])
    else:
        x = math.atan2(-R[1, 2], R[1, 1])
        y = math.atan2(-R[2, 0], sy)
        z = 0

    return np.array([x, y, z])

# Define 3D object points for the marker corners
obj_points = np.array([
    [-marker_length / 2, marker_length / 2, 0],
    [marker_length / 2, marker_length / 2, 0],
    [marker_length / 2, -marker_length / 2, 0],
    [-marker_length / 2, -marker_length / 2, 0]
], dtype=np.float32)

def align (heading_angle , robot_angle, alignment_tolerance = 0.05) :
    print(robot_angle)
    angle_difference = heading_angle - robot_angle
    if angle_difference > 180:
        angle_difference -= 360
    elif angle_difference < - 180 :
        angle_difference += 360

    print(abs(angle_difference))
    
    if abs ( angle_difference ) < alignment_tolerance :
        return True
    return False

#@tdmclient.notebook.sync_var
def andar ( left ,right ) :
    print("andar")
    global motor_right_target , motor_left_target
    

    motor_right_target = right
    motor_left_target = left



def detect_robot_and_ball(frame):
   
    # Convert the image to HSV color space
    hsv = cv.cvtColor(frame, cv.COLOR_BGR2HSV)

    # Define color ranges for the ball (green) and robot (white)
    green_lower = (35, 50, 50)    # Adjust based on your green ball's actual color
    green_upper = (85, 255, 255)  # Adjust based on your green ball's actual color


    # Threshold the image to get masks for green and white
    ball_mask = cv.inRange(hsv, green_lower, green_upper)


    # Find contours for the ball and robot
    ball_contours, _ = cv.findContours(ball_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

    # Initialize centroids as None
    ball_centroid = None

    # Find the largest contour for the ball (assuming it's the most significant green object)
    if ball_contours:
        ball_contour = max(ball_contours, key=cv.contourArea)
        ball_moments = cv.moments(ball_contour)
        if ball_moments['m00'] != 0:  # Avoid division by zero
            ball_centroid = (int(ball_moments['m10'] / ball_moments['m00']),
                             int(ball_moments['m01'] / ball_moments['m00']))

    return ball_centroid

def calculate_angle(marker_tvec, marker_rvec, ball_pos, camera_matrix, dist_coeffs):
    # Undistort the ball position
    ball_pos_undistorted = cv.undistortPoints(
        np.array([[ball_pos]], dtype=np.float32),
        camera_matrix,
        dist_coeffs
    )[0][0]  # Shape: (x, y)

    # Convert 2D ball position to 3D ray in the camera frame
    ball_ray_camera = np.array([ball_pos_undistorted[0], ball_pos_undistorted[1], 1.0])

    # Transform ball ray to the marker's coordinate frame
    rotation_matrix, _ = cv.Rodrigues(marker_rvec)
    ball_ray_marker = np.dot(rotation_matrix.T, ball_ray_camera - marker_tvec.flatten())

    # Calculate the angle between the Z-axis (marker forward) and the ball vector
    marker_forward = np.array([0, 0, 1])  # Z-axis in marker frame
    dot_product = np.dot(ball_ray_marker, marker_forward)
    ball_distance = np.linalg.norm(ball_ray_marker)  # Magnitude of ball vector

    angle_rad = np.arccos(dot_product / ball_distance)
    angle_deg = np.degrees(angle_rad)

    return angle_deg





# Load precomputed camera calibration parameters
data = np.load("calibration_data.npz")
mtx = data['camera_matrix']
dist = data['distortion_coefficients']

ip_webcam = "http://10.86.208.238:8080/video"

# Open the camera
#cap = cv.VideoCapture(0)  # Use the first camera (0 for default)
cap = cv.VideoCapture(ip_webcam)

# ArUco parameters
dictionary = cv.aruco.getPredefinedDictionary(cv.aruco.DICT_4X4_50)
parameters = cv.aruco.DetectorParameters()




# Marker length in the real-world coordinate system
marker_length = 0.07  # 10 cm (adjust based on your marker size)

if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

# Step 3: Show the undistorted camera feed
print("Press 'q' to quit the calibrated view.")
while True:
    ret, img = cap.read()
    if not ret:
        print("Error: Failed to capture image.")
        break

    img = cv.resize(img, (854, 480))

    # Detect markers
    corners, ids, rejected = cv.aruco.detectMarkers(img, dictionary, parameters=parameters)

    # Initialize arrays for pose estimation
    rvecs = []
    tvecs = []

    if ids is not None and len(ids) > 0:
        # Pose estimation for each detected marker
        for corner in corners:
            ret, rvec, tvec = cv.solvePnP(obj_points, corner, mtx, dist)
            rvecs.append(rvec)
            tvecs.append(tvec)

    
    
    
    # Draw detected markers
    frame_with_markers = img.copy()

    ball_pos = detect_robot_and_ball(frame_with_markers)
    
    if ids is not None:
        cv.aruco.drawDetectedMarkers(frame_with_markers, corners, ids)

        # Draw axes for pose estimation
        for rvec, tvec in zip(rvecs, tvecs):

            rotation_matrix, _ = cv.Rodrigues(rvec)

            # Get Euler angles
            euler_angles = rotation_matrix_to_euler_angles(rotation_matrix)

            # Print or use the Euler angles

            cv.drawFrameAxes(frame_with_markers, mtx, dist, rvec, tvec, marker_length * 1.5)

            if ball_pos:
                angle_to_ball = calculate_angle(tvec, rvec, ball_pos, mtx, dist)
                print(f"Angle to ball (degrees): {angle_to_ball}")
                cv.putText(frame_with_markers, f"Angle: {angle_to_ball:.2f}",
                           (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

                world_ball_pos = image_to_world(ball_pos, tvecs[0], rvecs[0])
                update_2d_env(tvecs[0], rvecs[0], world_ball_pos)
                
                if align(angle_to_ball, np.degrees(euler_angles)[2], 5) is False:
                    print()
                    #andar(-100,100)
                else: 
                    print()
                    #andar(0,0)

            
                

            
            

    

    # Draw the detected positions on the frame
    if ball_pos:
        cv.circle(frame_with_markers, ball_pos, 10, (0, 255, 0), -1)  # Green dot for the ball
        cv.putText(frame_with_markers, "Ball", ball_pos, cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    
    
    
    # Display the output
    cv.imshow("out", frame_with_markers)

    # Press 'q' to quit the loop
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close all windows
cap.release()
cv.destroyAllWindows()
# Out:
# Press 'q' to quit the calibrated view.
# Angle to ball (degrees): 130.5627114644289
# ball_pos:(array([-1.56279504, -3.83175438]), array([-1.40953396, -3.6784933 ]))
# -100.5590854595862
# 128.8782030759849
#
# Angle to ball (degrees): 130.4438321702432
# ball_pos:(array([-1.80114632, -4.22279559]), array([-1.64362171, -4.06527098]))
# -100.84608501084747
# 128.7100828189093
#
# Angle to ball (degrees): 129.64292764327882
# ball_pos:(array([-2.24883126, -5.12483358]), array([-2.08837354, -4.96437586]))
# -101.0170540901393
# 129.34001826658186
#
# Angle to ball (degrees): 128.4581611983762
# ball_pos:(array([-2.0958135 , -4.09236012]), array([-1.92022612, -3.91677273]))
# -101.62932298772017
# 129.91251581390364
#
# Angle to ball (degrees): 128.81115606206757
# ball_pos:(array([-2.03068032, -3.93053063]), array([-1.85192505, -3.75177537]))
# -101.22198779020269
# 129.96685614772974
#
# Angle to ball (degrees): 130.06238845465992
# ball_pos:(array([-1.91832291, -3.6147066 ]), array([-1.73028604, -3.42666973]))
# -100.34503468039038
# 129.5925768649497
#
# Angle to ball (degrees): 129.94189722032834
# ball_pos:(array([-1.88985873, -3.36230584]), array([-1.69314028, -3.16558739]))
# -101.01294558912768
# 129.045157190544
#
# Angle to ball (degrees): 129.57028671885237
# ball_pos:(array([-2.0849829 , -3.47518617]), array([-1.87900987, -3.26921315]))
# -102.54889524156032
# 127.88081803958733
#
# Angle to ball (degrees): 128.67091751780302
# ball_pos:(array([-1.85927904, -3.09952613]), array([-1.65909186, -2.89933895]))
# -102.94193680263139
# 128.3871456795656
#
# Angle to ball (degrees): 129.07441871358773
# ball_pos:(array([-1.85547214, -3.21524587]), array([-1.66097601, -3.02074974]))
# -102.25192217055601
# 128.67365911585625
#
# Angle to ball (degrees): 129.74198105282468
# ball_pos:(array([-1.84527705, -3.28135565]), array([-1.65382397, -3.08990257]))
# -101.46543522566874
# 128.79258372150656
#
# Angle to ball (degrees): 129.50195194994367
# ball_pos:(array([-1.80458352, -3.19347702]), array([-1.60937228, -2.99826578]))
# -101.13426418700558
# 129.36378386305074
#
# Angle to ball (degrees): 129.89707452953564
# ball_pos:(array([-1.76973017, -3.0777792 ]), array([-1.57139258, -2.8794416 ]))
# -101.14042115685119
# 128.96250431361318
#
# Angle to ball (degrees): 129.8757201199977
# ball_pos:(array([-1.80820313, -3.09920625]), array([-1.60878949, -2.89979261]))
# -101.49319730276409
# 128.6310825772382
#
# Angle to ball (degrees): 129.91341730840145
# ball_pos:(array([-1.82488484, -3.15714863]), array([-1.62608722, -2.958351  ]))
# -101.3278618563079
# 128.75872083529066
#
# Angle to ball (degrees): 129.73755007986512
# ball_pos:(array([-1.79775665, -3.10262937]), array([-1.60122715, -2.90609987]))
# -101.6650979030913
# 128.5973520170436
#
# Angle to ball (degrees): 129.8764961761887
# ball_pos:(array([-1.77762786, -3.06952627]), array([-1.58020154, -2.87209996]))
# -101.43583367394334
# 128.68767014986796
#
# Angle to ball (degrees): 129.78356872381676
# ball_pos:(array([-1.7954314 , -3.11931843]), array([-1.59722986, -2.92111689]))
# -101.26312673822211
# 128.95330453796112
#
# Angle to ball (degrees): 129.89498542346666
# ball_pos:(array([-1.77791125, -3.09213209]), array([-1.5799273 , -2.89414815]))
# -101.20931596922509
# 128.89569860730825
#
# Angle to ball (degrees): 129.51802027760363
# ball_pos:(array([-1.81882429, -3.12459351]), array([-1.620919  , -2.92668823]))
# -101.7699829340479
# 128.71199678834847
#
# Angle to ball (degrees): 129.6881867667204
# ball_pos:(array([-1.77283102, -3.05467457]), array([-1.57609044, -2.85793399]))
# -101.61521119627535
# 128.69660203700425
#
# Angle to ball (degrees): 129.73945600719782
# ball_pos:(array([-1.79418873, -3.11447054]), array([-1.59671611, -2.91699793]))
# -101.29495980970681
# 128.96558418309536
#
# Angle to ball (degrees): 129.81792760829177
# ball_pos:(array([-1.76277306, -3.01065537]), array([-1.56433241, -2.81221472]))
# -101.6230600333682
# 128.55901235834003
#
# Angle to ball (degrees): 130.32600679613986
# ball_pos:(array([-1.78265747, -3.0630776 ]), array([-1.58255541, -2.86297554]))
# -101.21366868728136
# 128.4603245165788
#
# Angle to ball (degrees): 130.08683765533183
# ball_pos:(array([-1.78207148, -3.04339943]), array([-1.58232073, -2.84364868]))
# -101.50037200586624
# 128.41279033880193
#
# Angle to ball (degrees): 129.97049465232482
# ball_pos:(array([-1.75307   , -3.00291218]), array([-1.55391826, -2.80376045]))
# -101.43612930157148
# 128.59337604610369
#
# Angle to ball (degrees): 130.18216773422216
# ball_pos:(array([-1.73068965, -2.98879145]), array([-1.53028917, -2.78839097]))
# -100.94768718660016
# 128.8701450791777
#
# Angle to ball (degrees): 129.94238325209562
# ball_pos:(array([-1.75244733, -2.96712432]), array([-1.55148467, -2.76616166]))
# -101.6129917829066
# 128.4446249649978
#
# Angle to ball (degrees): 130.12131994190213
# ball_pos:(array([-1.73370004, -2.93877589]), array([-1.53259517, -2.73767102]))
# -101.51910181247699
# 128.35957824562087
#
# Angle to ball (degrees): 130.22933472449898
# ball_pos:(array([-1.75526794, -2.96662837]), array([-1.55565649, -2.76701692]))
# -101.76601393423641
# 128.0046513412646
#
# Angle to ball (degrees): 130.12832311052546
# ball_pos:(array([-1.74099026, -2.98715819]), array([-1.54221354, -2.78838147]))
# -101.49882019142889
# 128.37285669804567
#
# Angle to ball (degrees): 130.21563892580923
# ball_pos:(array([-1.74625956, -2.99068394]), array([-1.54932151, -2.79374589]))
# -101.67820810236591
# 128.10615297182486
#
# Angle to ball (degrees): 130.1002788773004
# ball_pos:(array([-1.74745215, -3.0076526 ]), array([-1.54996195, -2.8101624 ]))
# -101.51049530642904
# 128.38922581627054
#
# Angle to ball (degrees): 130.00397014116237
# ball_pos:(array([-1.79053923, -3.06917454]), array([-1.59243216, -2.87106747]))
# -101.66660185301093
# 128.32942800582668
#
# Angle to ball (degrees): 130.16078179956097
# ball_pos:(array([-1.74060492, -2.99258825]), array([-1.54427102, -2.79625435]))
# -101.53444813603299
# 128.30477006440606
#
# Angle to ball (degrees): 130.0434500510841
# ball_pos:(array([-1.7891831 , -3.10069909]), array([-1.59260882, -2.9041248 ]))
# -101.4374203702739
# 128.51912957864198
#
# Angle to ball (degrees): 130.24787007742307
# ball_pos:(array([-1.76860497, -3.0682341 ]), array([-1.57410019, -2.87372931]))
# -101.52908831925595
# 128.22304160332098
#
# Angle to ball (degrees): 129.70342422867515
# ball_pos:(array([-1.78613864, -3.11796775]), array([-1.59210285, -2.92393196]))
# -101.59617577552358
# 128.70039999580126
#
# Angle to ball (degrees): 130.00511343563127
# ball_pos:(array([-1.76513728, -3.0854184 ]), array([-1.57211043, -2.89239155]))
# -101.50285695771218
# 128.49202960665656
#
# Angle to ball (degrees): 130.0194472279533
# ball_pos:(array([-1.8209162 , -3.21648248]), array([-1.62769662, -3.0232629 ]))
# -101.25866698251237
# 128.72188578953433
#
# Angle to ball (degrees): 129.62286839258272
# ball_pos:(array([-1.81261398, -3.18253083]), array([-1.61971412, -2.98963097]))
# -101.52264388853752
# 128.85448771887977
#
# Angle to ball (degrees): 129.53036439941556
# ball_pos:(array([-1.81104992, -3.1639404 ]), array([-1.62055468, -2.97344516]))
# -102.02839689189865
# 128.44123870868577
#
# Angle to ball (degrees): 130.10789478833877
# ball_pos:(array([-1.79452813, -3.20199074]), array([-1.60506952, -3.01253213]))
# -101.27948112856787
# 128.61262408309335
#
# Angle to ball (degrees): 129.76583694037612
# ball_pos:(array([-1.81226125, -3.22669895]), array([-1.62346246, -3.03790015]))
# -101.52367897408979
# 128.7104840855341
#
# Angle to ball (degrees): 129.77005694789608
# ball_pos:(array([-1.84612889, -3.2706132 ]), array([-1.65597392, -3.08045823]))
# -101.62852983546496
# 128.60141321663895
#
# Angle to ball (degrees): 129.9032775192873
# ball_pos:(array([-1.81761175, -3.22145522]), array([-1.62857761, -3.03242109]))
# -101.58292666720588
# 128.51379581350682
#
# Angle to ball (degrees): 129.62555753859388
# ball_pos:(array([-1.81471205, -3.22995283]), array([-1.62566356, -3.04090434]))
# -101.56739430191239
# 128.80704815949372
#
# Angle to ball (degrees): 129.84757254353985
# ball_pos:(array([-1.81218245, -3.20823188]), array([-1.62350579, -3.01955522]))
# -101.71056133952025
# 128.44186611693988
#
# Angle to ball (degrees): 130.2712319651202
# ball_pos:(array([-1.7910256 , -3.19452572]), array([-1.60223457, -3.00573469]))
# -101.257595913395
# 128.4711721214848
#
# Angle to ball (degrees): 130.01394520773363
# ball_pos:(array([-1.78559459, -3.17549518]), array([-1.59598819, -2.98588877]))
# -101.28060327489878
# 128.70545151736758
#
# Angle to ball (degrees): 130.01394520773363
# ball_pos:(array([-1.78559459, -3.17549518]), array([-1.59598819, -2.98588877]))
# -101.28060327489878
# 128.70545151736758
#
# Angle to ball (degrees): 130.25725450095223
# ball_pos:(array([-1.79826748, -3.19072497]), array([-1.60775716, -3.00021465]))
# [mjpeg @ 0x460ac00] overread 8
# -101.28709734739392
# 128.45564815165386
#
# Angle to ball (degrees): 130.03955989045437
# ball_pos:(array([-1.7710249 , -3.13647377]), array([-1.58107539, -2.94652427]))
# -101.43810069043522
# 128.5223394191104
#
# Angle to ball (degrees): 130.03955989045437
# ball_pos:(array([-1.7710249 , -3.13647377]), array([-1.58107539, -2.94652427]))
# -101.43810069043522
# 128.5223394191104
#
# Angle to ball (degrees): 130.54555879752198
# ball_pos:(array([-1.77286408, -3.13706415]), array([-1.5822085 , -2.94640857]))
# -101.19685741087045
# 128.25758379160757
#
# Angle to ball (degrees): 130.1895533009631
# ball_pos:(array([-1.76604535, -3.13232717]), array([-1.57641101, -2.94269283]))
# -101.37640011931872
# 128.4340465797182
#
# Angle to ball (degrees): 130.27366392502617
# ball_pos:(array([-1.77270594, -3.13131199]), array([-1.58390027, -2.94250633]))
# -101.56587781087359
# 128.16045826410024
#
# Angle to ball (degrees): 130.57388375809205
# ball_pos:(array([-1.74636834, -3.09553049]), array([-1.5580934 , -2.90725555]))
# -101.29288072126471
# 128.13323552064324
#
# Angle to ball (degrees): 130.7598125102821
# ball_pos:(array([-1.7790885 , -3.20235939]), array([-1.59060716, -3.01387806]))
# -100.89798018320285
# 128.34220730651504
#
# Angle to ball (degrees): 130.41056546568308
# ball_pos:(array([-1.79645603, -3.19191029]), array([-1.60959726, -3.00505152]))
# -101.52467152232252
# 128.0647630119944
#
# Angle to ball (degrees): 130.34861313395518
# ball_pos:(array([-1.79856545, -3.19977531]), array([-1.61117082, -3.01238069]))
# -101.51949375308959
# 128.13189311295523
#
# Angle to ball (degrees): 130.43970474867197
# ball_pos:(array([-1.79655433, -3.19662789]), array([-1.60955033, -3.0096239 ]))
# -101.49975377609803
# 128.06054147523
#
# Angle to ball (degrees): 130.43970474867197
# ball_pos:(array([-1.79655433, -3.19662789]), array([-1.60955033, -3.0096239 ]))
# -101.49975377609803
# 128.06054147523
# [mjpeg @ 0x460ac00] overread 8
# Angle to ball (degrees): 130.34477663712383
# ball_pos:(array([-1.76574591, -3.14601098]), array([-1.57874157, -2.95900664]))
# -101.43266024187535
# 128.2225631210008
#
# Angle to ball (degrees): 130.4603743204399
# ball_pos:(array([-1.74870206, -3.12740694]), array([-1.5617497 , -2.94045458]))
# -101.35707704977246
# 128.18254862978762
#
# Angle to ball (degrees): 130.28944867577616
# ball_pos:(array([-1.79363779, -3.19729452]), array([-1.60695604, -3.01061278]))
# -101.6194080465317
# 128.09114327769214
#
# Angle to ball (degrees): 130.44026758974536
# ball_pos:(array([-1.72604743, -3.10887446]), array([-1.5405639 , -2.92339093]))
# -101.25679557157896
# 128.3029368386757
#
# Angle to ball (degrees): 130.61902696466032
# ball_pos:(array([-1.74959153, -3.11120333]), array([-1.56363755, -2.92524935]))
# -101.50940899488052
# 127.87156404045916
#
# Angle to ball (degrees): 130.1835762937228
# ball_pos:(array([-1.79455332, -3.19022155]), array([-1.60763071, -3.00329893]))
# -101.66516631297443
# 128.15125739330276
#
# Angle to ball (degrees): 130.86587215807378
# ball_pos:(array([-1.75238262, -3.11670278]), array([-1.56475352, -2.92907368]))
# -101.32871323052403
# 127.80541461140217
#
# Angle to ball (degrees): 130.21851094673207
# ball_pos:(array([-1.74668722, -3.09372868]), array([-1.55982746, -2.90686891]))
# -101.73284786779621
# 128.04864118547172
#
# Angle to ball (degrees): 130.6135067728257
# ball_pos:(array([-1.74518955, -3.11173314]), array([-1.55755422, -2.9240978 ]))
# -101.32551379842408
# 128.06097942875022
#
# Angle to ball (degrees): 130.50660322829137
# ball_pos:(array([-1.7695556 , -3.15027255]), array([-1.58218512, -2.96290207]))
# -101.52188612271944
# 127.97151064898918
#
# Angle to ball (degrees): 130.5309210019049
# ball_pos:(array([-1.77240435, -3.15750046]), array([-1.58523425, -2.97033036]))
# -101.5361662923313
# 127.93291270576381
#
# Angle to ball (degrees): 130.3809035700869
# ball_pos:(array([-1.71938731, -3.09404268]), array([-1.53435726, -2.90901263]))
# -101.49244707522843
# 128.12664935468467
#
# Angle to ball (degrees): 130.70891431432423
# ball_pos:(array([-1.7489654 , -3.16009756]), array([-1.56240623, -2.97353839]))
# -101.19413184379334
# 128.09695384188242
#
# Angle to ball (degrees): 130.63679650650985
# ball_pos:(array([-1.7191922 , -3.11077213]), array([-1.53369333, -2.92527326]))
# -101.14069268706375
# 128.22251080642638
#
# Angle to ball (degrees): 130.48287330880174
# ball_pos:(array([-1.73867027, -3.14646792]), array([-1.5524337 , -2.96023134]))
# -101.18194745075101
# 128.33517924044725
#
# Angle to ball (degrees): 130.44856356514794
# ball_pos:(array([-1.7636512 , -3.18038442]), array([-1.57733446, -2.99406768]))
# -101.38336347557812
# 128.16807295927396
#
# Angle to ball (degrees): 130.54338965102758
# ball_pos:(array([-1.79451545, -3.23192759]), array([-1.60821253, -3.04562468]))
# -101.4515596696831
# 128.0050506792893
#
# Angle to ball (degrees): 130.61799985361236
# ball_pos:(array([-1.74441412, -3.16349961]), array([-1.55907287, -2.97815836]))
# -101.29422879057336
# 128.08777135581428
#
# Angle to ball (degrees): 130.52756185894927
# ball_pos:(array([-1.79613509, -3.24857559]), array([-1.61022012, -3.06266061]))
# -101.43137536562487
# 128.04106277542587
#
# Angle to ball (degrees): 130.65066153926318
# ball_pos:(array([-1.74329476, -3.15654213]), array([-1.55741672, -2.97066409]))
# -101.28675241755627
# 128.06258604318054
#
# Angle to ball (degrees): 130.75353798467088
# ball_pos:(array([-1.72405342, -3.1177561 ]), array([-1.53749669, -2.93119937]))
# -101.10217941429647
# 128.14428260103264
#
# Angle to ball (degrees): 130.8145082859516
# ball_pos:(array([-1.66919285, -3.01348438]), array([-1.48055877, -2.8248503 ]))
# -100.80569196092387
# 128.37979975312453
#
# Angle to ball (degrees): 130.59206171456933
# ball_pos:(array([-1.66911475, -2.99221226]), array([-1.48040224, -2.80349974]))
# -101.14943314794768
# 128.25850513748298
#
# Angle to ball (degrees): 130.61119152221553
# ball_pos:(array([-1.6691368 , -3.00020187]), array([-1.48026975, -2.81133482]))
# -101.12114535975245
# 128.26766311803203
#
# Angle to ball (degrees): 130.73915282057533
# ball_pos:(array([-1.67134265, -3.01811771]), array([-1.48260829, -2.82938335]))
# -100.911887113097
# 128.34896006632766
#
# Angle to ball (degrees): 130.88853606315976
# ball_pos:(array([-1.6849297 , -3.05322083]), array([-1.49609318, -2.86438431]))
# -100.8310246917972
# 128.28043924504306
#
# Angle to ball (degrees): 130.50620344382418
# ball_pos:(array([-1.64107357, -2.97840165]), array([-1.45296898, -2.79029706]))
# -100.93083629200639
# 128.56296026416942
#
# Angle to ball (degrees): 130.51544533198071
# ball_pos:(array([-1.68402955, -3.03838016]), array([-1.49584273, -2.85019334]))
# -101.21927668046335
# 128.26527798755592
#
# Angle to ball (degrees): 130.74004653500592
# ball_pos:(array([-1.65998974, -3.02911541]), array([-1.47206001, -2.84118568]))
# -100.75159766011775
# 128.50835580487632
#
# Angle to ball (degrees): 130.8624957754223
# ball_pos:(array([-1.65662647, -3.01858508]), array([-1.46853797, -2.83049658]))
# -100.72163102722011
# 128.4158731973576
#
# Angle to ball (degrees): 130.6810904639787
# ball_pos:(array([-1.67558183, -3.04768577]), array([-1.48738258, -2.85948652]))
# -100.93987197439871
# 128.37903756162257
#
# Angle to ball (degrees): 130.87375574974044
# ball_pos:(array([-1.66283694, -3.04554136]), array([-1.47378923, -2.85649364]))
# -100.5768189756988
# 128.54942527456075
#
# Angle to ball (degrees): 130.6854382662501
# ball_pos:(array([-1.68670104, -3.04170085]), array([-1.49809213, -2.85309194]))
# -101.08386160556043
# 128.23070012818948
#
# Angle to ball (degrees): 130.82302180343467
# ball_pos:(array([-1.64692189, -3.00261137]), array([-1.45836444, -2.81405392]))
# -100.63720439667894
# 128.5397737998864
#
# Angle to ball (degrees): 130.9734076912531
# ball_pos:(array([-1.67159331, -3.0263371 ]), array([-1.48211815, -2.83686193]))
# -100.71650204688994
# 128.31009026185694
#
# Angle to ball (degrees): 130.52505489960376
# ball_pos:(array([-1.68692108, -3.02416314]), array([-1.49749033, -2.83473239]))
# -101.17352587339094
# 128.30141922700528
#
# Angle to ball (degrees): 131.030269534685
# ball_pos:(array([-1.64806866, -2.99852088]), array([-1.45853984, -2.80899206]))
# -100.49041502938613
# 128.47931543592887
#
# Angle to ball (degrees): 130.9196196162573
# ball_pos:(array([-1.67498584, -2.99463722]), array([-1.48421241, -2.80386378]))
# -100.9619208291696
# 128.1184595545731
#
# Angle to ball (degrees): 130.4899584412647
# ball_pos:(array([-1.71059607, -3.02761039]), array([-1.51865321, -2.83566753]))
# -101.32209115411352
# 128.1879504046218
#
# Angle to ball (degrees): 130.58424665231198
# ball_pos:(array([-1.70682955, -3.04466633]), array([-1.51525249, -2.85308927]))
# -101.08524362237597
# 128.33050972531206
#
# Angle to ball (degrees): 130.5070380432047
# ball_pos:(array([-1.68682287, -3.02494803]), array([-1.49578962, -2.83391478]))
# -100.99998234166601
# 128.4929796151293
#
# Angle to ball (degrees): 130.64854096427757
# ball_pos:(array([-1.69151813, -3.03743056]), array([-1.50055466, -2.84646709]))
# -101.01805282215517
# 128.33340621356726
#
# Angle to ball (degrees): 130.5258222345385
# ball_pos:(array([-1.66671218, -2.9746105 ]), array([-1.47631255, -2.78421088]))
# -101.17289460811675
# 128.30128315734476
#
# Angle to ball (degrees): 130.45997072853217
# ball_pos:(array([-1.64681676, -2.94218567]), array([-1.45656919, -2.7519381 ]))
# -101.10803317062916
# 128.43199610083866
#
# Angle to ball (degrees): 130.63723488107718
# ball_pos:(array([-1.66967533, -3.01581796]), array([-1.4801905 , -2.82633313]))
# -100.92137422311163
# 128.4413908958112

# %%
# %matplotlib qt

# %%
import numpy as np
import cv2 as cv
import math

def rotation_matrix_to_euler_angles(R):
    sy = math.sqrt(R[0, 0] * R[0, 0] + R[1, 0] * R[1, 0])

    singular = sy < 1e-6

    if not singular:
        x = math.atan2(R[2, 1], R[2, 2])
        y = math.atan2(-R[2, 0], sy)
        z = math.atan2(R[1, 0], R[0, 0])
    else:
        x = math.atan2(-R[1, 2], R[1, 1])
        y = math.atan2(-R[2, 0], sy)
        z = 0

    return np.array([x, y, z])

# Termination criteria
criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# Prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((6*7, 3), np.float32)
objp[:, :2] = np.mgrid[0:7, 0:6].T.reshape(-1, 2)

# Arrays to store object points and image points
objpoints = []  # 3D points in real-world space
imgpoints = []  # 2D points in image plane

# Open the camera
cap = cv.VideoCapture(0)  # Use the first camera (0 for default)
#cap = cv.VideoCapture("http://192.168.1.77:8080/video")

if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

# Step 1: Collect calibration data
print("Press 'q' to quit the calibration phase.")
while True:
    ret, img = cap.read()
    if not ret:
        print("Error: Failed to capture image.")
        break

    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

    # Find the chessboard corners
    ret, corners = cv.findChessboardCorners(gray, (7, 6), None)

    # If found, add object points, image points (after refining them)
    if ret:
        objpoints.append(objp)
        corners2 = cv.cornerSubPix(gray, corners, (11, 11), (-1, -1), criteria)
        imgpoints.append(corners2)

        # Draw and display the corners
        cv.drawChessboardCorners(img, (7, 6), corners2, ret)

    # Show the image with detected corners
    cv.imshow('Chessboard Calibration', img)

    # Press 'q' to quit the calibration phase
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera temporarily
cap.release()
cv.destroyAllWindows()

# Step 2: Perform calibration
if len(objpoints) > 0:
    ret, mtx, dist, rvecs, tvecs = cv.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
    print("Camera matrix:\n", mtx)
    print("Distortion coefficients:\n", dist)
else:
    print("Not enough corners detected for calibration.")
    exit()

# ArUco parameters
dictionary = cv.aruco.getPredefinedDictionary(cv.aruco.DICT_4X4_50)
parameters = cv.aruco.DetectorParameters()



# Marker length in the real-world coordinate system
marker_length = 0.07  # 10 cm (adjust based on your marker size)

# Define 3D object points for the marker corners
obj_points = np.array([
    [-marker_length / 2, marker_length / 2, 0],
    [marker_length / 2, marker_length / 2, 0],
    [marker_length / 2, -marker_length / 2, 0],
    [-marker_length / 2, -marker_length / 2, 0]
], dtype=np.float32)

# Step 3: Show the undistorted camera feed
cap = cv.VideoCapture(0)  # Re-open the camera
#cap = cv.VideoCapture("http://192.168.1.77:8080/video")

if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

print("Press 'q' to quit the calibrated view.")
while True:
    ret, img = cap.read()
    if not ret:
        print("Error: Failed to capture image.")
        break

    #cv.imshow('Original', img)
    #cv.imshow('Undistorted', undistorted)

     # Detect markers
    corners, ids, rejected = cv.aruco.detectMarkers(img, dictionary, parameters=parameters)

    # Initialize arrays for pose estimation
    rvecs = []
    tvecs = []

    if ids is not None and len(ids) > 0:
        # Pose estimation for each detected marker
        for corner in corners:
            ret, rvec, tvec = cv.solvePnP(obj_points, corner, mtx, dist)
            rvecs.append(rvec)
            tvecs.append(tvec)


    # Draw detected markers
    frame_with_markers = img.copy()
    if ids is not None:
        cv.aruco.drawDetectedMarkers(frame_with_markers, corners, ids)

        # Draw axes for pose estimation
        for rvec, tvec in zip(rvecs, tvecs):
            rotation_matrix, _ = cv.Rodrigues(rvec)

            # Get Euler angles
            euler_angles = rotation_matrix_to_euler_angles(rotation_matrix)
        
            # Print or use the Euler angles
            print("Marker Rotation (Euler angles in degrees):", np.degrees(euler_angles))
            
            cv.drawFrameAxes(frame_with_markers, mtx, dist, rvec, tvec, marker_length * 1.5)

    # Display the output
    cv.imshow("out", frame_with_markers)
    
    # Press 'q' to quit the loop
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close all windows
cap.release()
cv.destroyAllWindows()
# Out:
# Press 'q' to quit the calibration phase.
# Camera matrix:
#  [[9.49794764e+03 0.00000000e+00 3.20125471e+02]
#  [0.00000000e+00 1.54967534e+04 2.53881933e+02]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
# Distortion coefficients:
#  [[ 2.87554319e+01 -2.11703746e+04 -1.66692835e-01  4.12558996e-01
#   -2.30075745e+01]]
# Press 'q' to quit the calibrated view.
# Marker Rotation (Euler angles in degrees): [170.16247222 -53.04158441 -83.09567017]
# Marker Rotation (Euler angles in degrees): [171.80801647 -53.5491836  -83.74524321]
# Marker Rotation (Euler angles in degrees): [170.05717621 -53.55205493 -81.94211314]
# Marker Rotation (Euler angles in degrees): [169.22568999 -53.22009305 -81.51884081]
# Marker Rotation (Euler angles in degrees): [170.67144709 -53.13014914 -82.55620126]
# Marker Rotation (Euler angles in degrees): [170.42994234 -53.47128581 -82.4322711 ]
# Marker Rotation (Euler angles in degrees): [168.09863636 -52.84997182 -80.58522596]
# Marker Rotation (Euler angles in degrees): [174.19302916 -54.00227367 -85.53007325]
# Marker Rotation (Euler angles in degrees): [178.09777375 -54.35176968 -88.30881932]
# Marker Rotation (Euler angles in degrees): [175.67815985 -53.32295507 -85.72726655]
# Marker Rotation (Euler angles in degrees): [172.28981401 -53.29465702 -82.45893053]
# Marker Rotation (Euler angles in degrees): [171.99184472 -53.25294199 -82.46432947]
# Marker Rotation (Euler angles in degrees): [174.11084911 -53.13793769 -84.16000752]
# Marker Rotation (Euler angles in degrees): [172.92693886 -53.06257483 -83.06701082]
# Marker Rotation (Euler angles in degrees): [172.29737227 -53.0322589  -82.67196002]
# Marker Rotation (Euler angles in degrees): [172.00003691 -52.66874522 -82.31669998]
# Marker Rotation (Euler angles in degrees): [172.44004221 -52.18588981 -82.68930886]
# Marker Rotation (Euler angles in degrees): [172.15328961 -53.09478267 -82.26499634]
# Marker Rotation (Euler angles in degrees): [171.67043127 -52.58299549 -81.88907906]
# Marker Rotation (Euler angles in degrees): [172.00317045 -52.87016894 -81.87648133]
# Marker Rotation (Euler angles in degrees): [172.28179571 -52.87212078 -82.22543512]
# Marker Rotation (Euler angles in degrees): [171.38952744 -53.13770128 -81.47479138]
# Marker Rotation (Euler angles in degrees): [170.93473512 -52.94496062 -81.11073543]
# Marker Rotation (Euler angles in degrees): [170.76098061 -53.09603309 -81.07656188]
# Marker Rotation (Euler angles in degrees): [170.99169208 -53.73637988 -81.33100705]
# Marker Rotation (Euler angles in degrees): [170.50363141 -53.24553456 -80.96137082]
# Marker Rotation (Euler angles in degrees): [169.77278252 -53.34628105 -80.22614287]
# Marker Rotation (Euler angles in degrees): [169.69155194 -53.38545357 -80.53536507]
# Marker Rotation (Euler angles in degrees): [169.3721574  -53.97752797 -80.08555495]
# Marker Rotation (Euler angles in degrees): [168.39593524 -53.93011517 -79.27960159]
# Marker Rotation (Euler angles in degrees): [168.02967774 -54.24771008 -79.19666174]
# Marker Rotation (Euler angles in degrees): [167.58561021 -54.06845109 -78.8443521 ]
# Marker Rotation (Euler angles in degrees): [167.69827389 -54.21424644 -78.78868041]
# Marker Rotation (Euler angles in degrees): [166.87456842 -54.59996901 -77.92477381]
# Marker Rotation (Euler angles in degrees): [165.59864561 -54.80082145 -76.6929724 ]
# Marker Rotation (Euler angles in degrees): [165.55491223 -54.53908739 -77.07924397]
# Marker Rotation (Euler angles in degrees): [166.699897   -54.93241796 -78.11200034]
# Marker Rotation (Euler angles in degrees): [166.90367286 -54.92111602 -78.00839611]
# Marker Rotation (Euler angles in degrees): [166.54926774 -54.8818102  -77.57864146]
# Marker Rotation (Euler angles in degrees): [166.14614644 -55.19254722 -77.46356378]
# Marker Rotation (Euler angles in degrees): [166.53813651 -55.67066076 -77.73117816]
# Marker Rotation (Euler angles in degrees): [165.90177023 -55.29087562 -76.97004736]
# Marker Rotation (Euler angles in degrees): [165.21585057 -55.25878471 -76.52528932]
# Marker Rotation (Euler angles in degrees): [165.02434647 -55.41432655 -76.47229695]
# Marker Rotation (Euler angles in degrees): [165.09954632 -56.20252655 -77.35711476]
# Marker Rotation (Euler angles in degrees): [163.49769809 -55.31204633 -76.00148884]
# Marker Rotation (Euler angles in degrees): [164.22459184 -56.47980245 -75.64721539]
# Marker Rotation (Euler angles in degrees): [164.92262379 -55.90968289 -76.19334322]
# Marker Rotation (Euler angles in degrees): [164.82886874 -56.46972845 -75.64390755]
# Marker Rotation (Euler angles in degrees): [165.10167227 -56.00716066 -75.81473474]
# Marker Rotation (Euler angles in degrees): [165.74999359 -56.56343894 -76.42651361]
# Marker Rotation (Euler angles in degrees): [163.61334291 -56.5945474  -74.71915754]
# Marker Rotation (Euler angles in degrees): [162.25863179 -57.97691232 -74.28297602]
# Marker Rotation (Euler angles in degrees): [162.05457023 -62.35771987 -73.05225023]
# Marker Rotation (Euler angles in degrees): [ -96.53872979  -52.31997673 -169.94398342]
# Marker Rotation (Euler angles in degrees): [ -96.07902433  -52.38855286 -170.6395322 ]
# Marker Rotation (Euler angles in degrees): [157.08732699 -65.62927261 -67.46143984]
# Marker Rotation (Euler angles in degrees): [157.80693186 -65.70690025 -68.68208755]
# Marker Rotation (Euler angles in degrees): [157.62532804 -66.11309494 -68.3172638 ]
# Marker Rotation (Euler angles in degrees): [157.10547611 -66.01991374 -67.55875042]
# Marker Rotation (Euler angles in degrees): [156.32292384 -66.56329911 -67.44910796]
# Marker Rotation (Euler angles in degrees): [155.55166932 -66.79640499 -66.54984483]
# Marker Rotation (Euler angles in degrees): [154.72685359 -66.82141017 -66.04564669]
# Marker Rotation (Euler angles in degrees): [ 97.1254521  -58.53538787 -10.05202752]
# Marker Rotation (Euler angles in degrees): [ 93.6225472  -47.07441326 -16.99503387]
# Marker Rotation (Euler angles in degrees): [ 93.57487945 -47.09816948 -16.73014732]
# Marker Rotation (Euler angles in degrees): [ 93.46729387 -47.12096163 -16.47331005]
# Marker Rotation (Euler angles in degrees): [ 93.31996072 -47.22709973 -15.73379233]
# Marker Rotation (Euler angles in degrees): [ 93.17289971 -47.21724171 -15.21312468]
# Marker Rotation (Euler angles in degrees): [ 93.0510328  -47.28639569 -14.58803706]
# Marker Rotation (Euler angles in degrees): [150.87067129 -70.74556337 -61.92057037]
# Marker Rotation (Euler angles in degrees): [ 95.68323569 -59.05407682  -8.66192498]
# Marker Rotation (Euler angles in degrees): [149.52097697 -71.64284656 -60.75875299]
# Marker Rotation (Euler angles in degrees): [ -92.97619852  -50.75518494 -171.14587671]
# Marker Rotation (Euler angles in degrees): [ 95.53873034 -59.23501584  -8.67158413]
# Marker Rotation (Euler angles in degrees): [ 92.6146856  -47.34901849 -12.91097253]
# Marker Rotation (Euler angles in degrees): [147.51071613 -73.49370865 -58.28341155]
# Marker Rotation (Euler angles in degrees): [147.5016589  -73.49576056 -58.27698016]
# Marker Rotation (Euler angles in degrees): [ -92.66565799  -50.82705873 -172.68988224]
# Marker Rotation (Euler angles in degrees): [ -93.16755942  -50.6648262  -169.26355352]
# Marker Rotation (Euler angles in degrees): [ -93.4276221   -50.61471279 -168.38732369]
# Marker Rotation (Euler angles in degrees): [ -93.27097696  -50.61828672 -169.52836686]
# Marker Rotation (Euler angles in degrees): [ -93.07625398  -50.6854105  -170.34101128]
# Marker Rotation (Euler angles in degrees): [ -92.8597477   -50.66729957 -170.05580598]
# Marker Rotation (Euler angles in degrees): [ -92.53579057  -50.72089566 -171.33068632]
# Marker Rotation (Euler angles in degrees): [ -92.14212963  -50.75249693 -173.60036022]
# Marker Rotation (Euler angles in degrees): [ -92.21319405  -50.68762572 -172.51063772]
# Marker Rotation (Euler angles in degrees): [ -91.92841578  -50.52205315 -174.44411094]
# Marker Rotation (Euler angles in degrees): [ -92.0297526   -50.50826153 -173.46996164]
# Marker Rotation (Euler angles in degrees): [ -92.01655326  -50.43071717 -174.14193119]
# Marker Rotation (Euler angles in degrees): [159.12704497 -76.94200236 -69.00976608]
# Marker Rotation (Euler angles in degrees): [ 92.55614429 -47.0759992  -15.67263344]
# Marker Rotation (Euler angles in degrees): [ 95.03820937 -59.15417176  -9.38714336]
# Marker Rotation (Euler angles in degrees): [ 92.05578528 -46.90669047 -14.41490675]
# Marker Rotation (Euler angles in degrees): [ 91.95911617 -46.70244742 -14.72277493]
# Marker Rotation (Euler angles in degrees): [ 92.04558181 -46.60021184 -15.23058831]
# Marker Rotation (Euler angles in degrees): [ 92.08171374 -46.50851445 -15.33204823]
# Marker Rotation (Euler angles in degrees): [ 92.04542786 -46.48058664 -15.08870144]
# Marker Rotation (Euler angles in degrees): [ 91.97587046 -46.30883749 -15.05275255]
# Marker Rotation (Euler angles in degrees): [ 92.08054366 -46.23180999 -15.37139411]
# Marker Rotation (Euler angles in degrees): [160.56586106 -70.20324153 -71.69997921]
# Marker Rotation (Euler angles in degrees): [ 96.00014745 -59.3296245  -11.81225046]
# Marker Rotation (Euler angles in degrees): [162.84832897 -69.40501627 -73.6059603 ]
# Marker Rotation (Euler angles in degrees): [162.08332039 -69.36008514 -72.52749946]
# Marker Rotation (Euler angles in degrees): [162.75792696 -69.00450405 -72.85006399]
# Marker Rotation (Euler angles in degrees): [163.11026639 -68.83302687 -73.02737777]
# Marker Rotation (Euler angles in degrees): [163.94364241 -67.92753894 -73.73190933]
# Marker Rotation (Euler angles in degrees): [164.71780951 -67.30460309 -73.67043622]
# Marker Rotation (Euler angles in degrees): [ -94.05148832  -53.52811908 -177.07994028]
# Marker Rotation (Euler angles in degrees): [ -95.0023439   -44.77587108 -105.59872151]
# Marker Rotation (Euler angles in degrees): [161.98669477 -56.21704607 -71.53908702]
# Marker Rotation (Euler angles in degrees): [170.05649223  53.61175286 -99.97007855]
# Marker Rotation (Euler angles in degrees): [-172.96983125  -52.78297632  -97.49920794]
# Marker Rotation (Euler angles in degrees): [-175.94835984  -51.11065573  -94.46458388]
# Marker Rotation (Euler angles in degrees): [-176.82056168  -52.81586819  -92.88668985]
# Marker Rotation (Euler angles in degrees): [-176.1861384   -52.21067392  -92.89054741]
# Marker Rotation (Euler angles in degrees): [-178.86215003  -52.45115274  -89.76468165]
# Marker Rotation (Euler angles in degrees): [178.86309767 -52.47794817 -87.99147383]
# Marker Rotation (Euler angles in degrees): [179.23533016 -52.49703641 -88.46295248]
# Marker Rotation (Euler angles in degrees): [179.5583393  -52.09589835 -88.90032208]
# Marker Rotation (Euler angles in degrees): [-179.54009757  -52.72301821  -89.79533364]
# Marker Rotation (Euler angles in degrees): [-178.99117517  -52.11207817  -90.23383112]
# Marker Rotation (Euler angles in degrees): [-179.97393231  -52.70959758  -89.78414818]
# Marker Rotation (Euler angles in degrees): [-178.96327968  -51.88570543  -91.0618411 ]
# Marker Rotation (Euler angles in degrees): [179.02028465  53.04202267 -90.70509217]
# Marker Rotation (Euler angles in degrees): [-179.10588056  -52.48829757  -90.63764029]
# Marker Rotation (Euler angles in degrees): [-178.39566275  -52.46229241  -91.03735496]
# Marker Rotation (Euler angles in degrees): [179.98333215 -51.84711618 -89.74523534]
# Marker Rotation (Euler angles in degrees): [179.47806809 -52.05204093 -88.86235701]
# Marker Rotation (Euler angles in degrees): [178.91462355 -52.24759064 -88.41885231]
# Marker Rotation (Euler angles in degrees): [179.59113455 -52.24864273 -89.28026506]
# Marker Rotation (Euler angles in degrees): [179.71819736 -52.45058975 -89.70265851]
# Marker Rotation (Euler angles in degrees): [179.52845688  52.30894289 -90.7871174 ]
# Marker Rotation (Euler angles in degrees): [179.97827125 -51.60145501 -90.57275147]
# Marker Rotation (Euler angles in degrees): [-179.68128137  -51.59132356  -91.01026692]
# Marker Rotation (Euler angles in degrees): [179.63735594 -51.36326304 -90.99123578]
# Marker Rotation (Euler angles in degrees): [179.6243718  -51.35311094 -90.99594954]
# Marker Rotation (Euler angles in degrees): [179.56857166 -49.98985925 -90.98800027]
# Marker Rotation (Euler angles in degrees): [178.76554669 -50.43689211 -90.54566341]
# Marker Rotation (Euler angles in degrees): [178.96169271 -49.72604512 -90.54755153]
# Marker Rotation (Euler angles in degrees): [177.47793691 -48.97923017 -89.64527823]
# Marker Rotation (Euler angles in degrees): [177.1489855  -48.66153096 -89.6255801 ]
# Marker Rotation (Euler angles in degrees): [175.09904395 -47.88264671 -88.72026675]
# Marker Rotation (Euler angles in degrees): [175.1892476  -46.48394433 -88.73109181]
# Marker Rotation (Euler angles in degrees): [173.11139857 -45.25824368 -87.79225978]
# Marker Rotation (Euler angles in degrees): [172.86434302 -43.95683903 -87.7961945 ]
# Marker Rotation (Euler angles in degrees): [173.16478295 -41.86095444 -88.72231602]
# Marker Rotation (Euler angles in degrees): [172.77506162 -41.81565008 -88.27063998]
# Marker Rotation (Euler angles in degrees): [174.06161766 -41.12139117 -89.19445128]
# Marker Rotation (Euler angles in degrees): [174.79565331 -39.16952237 -90.1223336 ]
# Marker Rotation (Euler angles in degrees): [177.83595705 -37.74047632 -91.92929597]
# Marker Rotation (Euler angles in degrees): [179.20078477  36.75177603 -93.99527156]
# Marker Rotation (Euler angles in degrees): [-178.26943386  -34.15855877  -94.60760788]
# Marker Rotation (Euler angles in degrees): [178.56255937 -34.57436325 -93.29083902]
# Marker Rotation (Euler angles in degrees): [176.11619209 -34.24449072 -91.93910498]
# Marker Rotation (Euler angles in degrees): [174.11189597 -32.76251728 -91.4829946 ]
# Marker Rotation (Euler angles in degrees): [172.79907951 -31.09170533 -91.03765749]
# Marker Rotation (Euler angles in degrees): [172.44352056 -31.58226104 -91.03292032]
# Marker Rotation (Euler angles in degrees): [169.22271187 -32.14682895 -89.20976353]
# Marker Rotation (Euler angles in degrees): [168.99640964 -31.86375063 -89.20363071]
# Marker Rotation (Euler angles in degrees): [169.89833076 -30.57608918 -89.68033844]
# Marker Rotation (Euler angles in degrees): [171.07738738 -27.72530719 -91.04771213]
# Marker Rotation (Euler angles in degrees): [171.99437781 -24.73464799 -91.945403  ]
# Marker Rotation (Euler angles in degrees): [170.03321673 -25.63877789 -91.50488749]
# Marker Rotation (Euler angles in degrees): [ 94.28566914 -43.49939296 -11.27950276]
# Marker Rotation (Euler angles in degrees): [ 94.55106962 -45.9396893  -38.48514515]
# Marker Rotation (Euler angles in degrees): [ 94.48592014 -45.91481664 -38.3646606 ]
# Marker Rotation (Euler angles in degrees): [ 94.50189431 -45.84696391 -39.43777853]
# Marker Rotation (Euler angles in degrees): [152.19434213 -18.5401019  -87.88894992]
# Marker Rotation (Euler angles in degrees): [ 94.33783656 -45.7617266  -38.67820055]
# Marker Rotation (Euler angles in degrees): [ 94.30800391 -45.74732136 -38.51085931]
# Marker Rotation (Euler angles in degrees): [ 94.35436591 -45.64481462 -40.61542991]
# Marker Rotation (Euler angles in degrees): [ 94.15616956 -45.67412002 -37.36656132]
# Marker Rotation (Euler angles in degrees): [140.65955955 -13.97642811 -87.02510705]
# Marker Rotation (Euler angles in degrees): [139.00747622 -12.90942882 -87.48707088]
# Marker Rotation (Euler angles in degrees): [ 94.07072766 -45.70814842 -35.50588729]
# Marker Rotation (Euler angles in degrees): [ 94.03086338 -45.49220915 -39.93800236]
# Marker Rotation (Euler angles in degrees): [ 93.99217908 -42.34218137 -11.17691179]
# Marker Rotation (Euler angles in degrees): [ 93.99472452 -45.44598498 -39.73147806]
# Marker Rotation (Euler angles in degrees): [ 93.97869991 -45.62719497 -35.34101505]
# Marker Rotation (Euler angles in degrees): [137.48029158 -14.39683609 -86.53368441]
# Marker Rotation (Euler angles in degrees): [ 93.92632775 -45.65755872 -35.89754277]
# Marker Rotation (Euler angles in degrees): [ 93.86807939 -45.68925806 -34.69088264]
# Marker Rotation (Euler angles in degrees): [143.38567956 -22.94712744 -82.25504924]
# Marker Rotation (Euler angles in degrees): [ 94.12875088 -45.82995639 -36.33106702]
# Marker Rotation (Euler angles in degrees): [150.74867398 -27.68963898 -82.65013734]
# Marker Rotation (Euler angles in degrees): [151.3180223  -32.55422948 -80.32281024]
# Marker Rotation (Euler angles in degrees): [153.10521208 -36.08584513 -79.74862131]
# Marker Rotation (Euler angles in degrees): [ 94.49007091 -46.28733887 -35.36233161]
# Marker Rotation (Euler angles in degrees): [162.88126789 -41.29683022 -83.97590474]
# Marker Rotation (Euler angles in degrees): [164.86436406 -42.87842696 -84.43529024]
# Marker Rotation (Euler angles in degrees): [163.68632259 -45.43900304 -82.48118288]
# Marker Rotation (Euler angles in degrees): [163.17555804 -48.26529453 -81.38552757]
# Marker Rotation (Euler angles in degrees): [164.74333043 -49.53182783 -81.87435328]
# Marker Rotation (Euler angles in degrees): [164.04794058 -51.20572377 -80.76790455]
# Marker Rotation (Euler angles in degrees): [162.84455671 -52.72000856 -79.09620553]
# Marker Rotation (Euler angles in degrees): [162.58572594 -54.50160857 -78.87717377]
# Marker Rotation (Euler angles in degrees): [ 86.3821396  -43.52135777 -28.50855977]
# Marker Rotation (Euler angles in degrees): [ 94.81467939 -46.71829185 -32.99212439]
# Marker Rotation (Euler angles in degrees): [ 94.92514083 -46.76616418 -33.97089488]
# Marker Rotation (Euler angles in degrees): [164.77241129 -55.69852441 -80.99468138]
# Marker Rotation (Euler angles in degrees): [ 94.83858223 -46.65526074 -35.39880356]
# Marker Rotation (Euler angles in degrees): [ 94.62090094 -46.86499549 -31.21510562]
# Marker Rotation (Euler angles in degrees): [ 94.06245973 -46.88411941 -28.54984162]
# Marker Rotation (Euler angles in degrees): [ 93.83759549 -46.92825874 -26.43267564]
# Marker Rotation (Euler angles in degrees): [161.54404269 -66.13846038 -75.35305435]
# Marker Rotation (Euler angles in degrees): [ 92.95276748 -47.12259926 -19.02819604]
# Marker Rotation (Euler angles in degrees): [ 92.69562569 -47.16506166 -17.20465274]
# Marker Rotation (Euler angles in degrees): [ 92.55528539 -47.18253366 -16.3567506 ]
# Marker Rotation (Euler angles in degrees): [ 92.38195112 -47.20226659 -14.7610236 ]
# Marker Rotation (Euler angles in degrees): [ 92.11827251 -47.23931871 -13.20207155]
# Marker Rotation (Euler angles in degrees): [ 91.23884857 -45.37289015 -13.40138446]
# Marker Rotation (Euler angles in degrees): [ 91.73265057 -45.02724063 -17.14213044]
# Marker Rotation (Euler angles in degrees): [ 91.90577899 -45.1473889  -14.7291743 ]
# Marker Rotation (Euler angles in degrees): [ 92.09616545 -45.19088125 -13.09747427]
# Marker Rotation (Euler angles in degrees): [ 92.0568631  -45.07859767 -15.33260302]
# Marker Rotation (Euler angles in degrees): [ 92.01386175 -45.04040098 -16.60628203]
# Marker Rotation (Euler angles in degrees): [ 92.06282511 -45.04314157 -18.31441706]
# Marker Rotation (Euler angles in degrees): [ 92.14377281 -45.031323   -19.45504359]
# Marker Rotation (Euler angles in degrees): [ 92.30027723 -45.15605474 -15.38600282]
# Marker Rotation (Euler angles in degrees): [ 92.26826751 -44.96664479 -19.99304611]
# Marker Rotation (Euler angles in degrees): [ 92.23044658 -44.96157092 -19.65173532]
# Marker Rotation (Euler angles in degrees): [ 92.27208745 -44.97977142 -19.54246892]
# Marker Rotation (Euler angles in degrees): [ 92.34539007 -45.03445111 -16.97168349]
# Marker Rotation (Euler angles in degrees): [ 92.246826   -44.95525469 -19.30542692]
# Marker Rotation (Euler angles in degrees): [ 92.25686333 -44.93646439 -15.41643387]
# Marker Rotation (Euler angles in degrees): [ 92.21982564 -44.76011875 -18.78354763]
# Marker Rotation (Euler angles in degrees): [ 99.58155095 -57.38263806 -20.35515792]
# Marker Rotation (Euler angles in degrees): [152.46953543 -56.81863354 -66.60673719]
# Marker Rotation (Euler angles in degrees): [ 99.77719597 -56.94514129 -20.62595884]
# Marker Rotation (Euler angles in degrees): [100.19957889 -57.01955187 -21.00614165]
# Marker Rotation (Euler angles in degrees): [100.50552437 -57.00652489 -21.19110317]
# Marker Rotation (Euler angles in degrees): [153.95474845 -54.01884664 -68.08578806]
# Marker Rotation (Euler angles in degrees): [154.21322826 -53.81292764 -68.18776813]
# Marker Rotation (Euler angles in degrees): [100.9335325  -57.19632896 -21.78277995]
# Marker Rotation (Euler angles in degrees): [100.90102067 -57.31173285 -21.6351121 ]
# Marker Rotation (Euler angles in degrees): [100.79616688 -57.20809159 -21.64956369]
# Marker Rotation (Euler angles in degrees): [100.65759911 -56.94962493 -21.51539573]
# Marker Rotation (Euler angles in degrees): [100.61288075 -56.97703837 -21.49135446]
# Marker Rotation (Euler angles in degrees): [100.71989202 -57.21026529 -21.76961426]
# Marker Rotation (Euler angles in degrees): [100.83141675 -57.20051357 -21.87116053]
# Marker Rotation (Euler angles in degrees): [101.0766342  -57.30134212 -22.04680872]
# Marker Rotation (Euler angles in degrees): [101.25578964 -57.43196977 -22.21346657]
# Marker Rotation (Euler angles in degrees): [101.14276291 -57.34544025 -22.18506704]
# Marker Rotation (Euler angles in degrees): [151.5824596  -53.80716275 -66.12198326]
# Marker Rotation (Euler angles in degrees): [101.20562742 -57.46139874 -22.30271244]
# Marker Rotation (Euler angles in degrees): [152.48746288 -54.32138181 -66.7701951 ]
# Marker Rotation (Euler angles in degrees): [152.0092471  -54.43679637 -66.32700409]
# Marker Rotation (Euler angles in degrees): [101.01249644 -57.58588306 -22.07643346]
# Marker Rotation (Euler angles in degrees): [101.0118646 -57.395574  -22.0944472]
# Marker Rotation (Euler angles in degrees): [101.1706402  -57.50818893 -22.23529824]
# Marker Rotation (Euler angles in degrees): [101.05415856 -57.17585893 -22.0855382 ]
# Marker Rotation (Euler angles in degrees): [152.38283532 -54.40234693 -66.31676163]
# Marker Rotation (Euler angles in degrees): [152.74057688 -54.12028212 -66.87429283]
# Marker Rotation (Euler angles in degrees): [152.06422404 -54.15388036 -66.11370565]
# Marker Rotation (Euler angles in degrees): [101.13690204 -57.36083881 -22.31466877]
# Marker Rotation (Euler angles in degrees): [101.04393367 -57.31264697 -22.05707767]
# Marker Rotation (Euler angles in degrees): [151.46180867 -54.4299209  -65.33423974]
# Marker Rotation (Euler angles in degrees): [100.97204973 -57.17486603 -22.0736787 ]
# Marker Rotation (Euler angles in degrees): [151.64128369 -54.73360153 -65.76949736]
# Marker Rotation (Euler angles in degrees): [100.90809269 -57.16713881 -22.13088872]
# Marker Rotation (Euler angles in degrees): [150.53507853 -55.10065976 -64.52229974]
# Marker Rotation (Euler angles in degrees): [149.77142034 -54.51741142 -63.64015393]
# Marker Rotation (Euler angles in degrees): [100.62646254 -57.04259387 -21.6943473 ]
# Marker Rotation (Euler angles in degrees): [100.66349295 -56.9453135  -21.72361796]
# Marker Rotation (Euler angles in degrees): [100.59258768 -56.76737334 -21.72874735]
# Marker Rotation (Euler angles in degrees): [100.48765002 -56.83637185 -21.55178914]
# Marker Rotation (Euler angles in degrees): [148.35257466 -54.38336723 -62.77463601]
# Marker Rotation (Euler angles in degrees): [148.3506172  -54.37758072 -62.77184401]
# Marker Rotation (Euler angles in degrees): [100.75446901 -56.81705894 -22.21941614]
# Marker Rotation (Euler angles in degrees): [100.47827781 -56.87711566 -21.99874431]
# Marker Rotation (Euler angles in degrees): [100.50974753 -56.80136084 -22.03605604]
# Marker Rotation (Euler angles in degrees): [150.45237088 -54.62639384 -64.91010726]
# Marker Rotation (Euler angles in degrees): [149.87255767 -54.34890486 -64.46718055]
# Marker Rotation (Euler angles in degrees): [100.0824917  -56.48792368 -21.70786313]
# Marker Rotation (Euler angles in degrees): [100.08927755 -56.47800263 -21.76824886]
# Marker Rotation (Euler angles in degrees): [ 99.97229707 -56.30045919 -21.67787828]
# Marker Rotation (Euler angles in degrees): [ 99.96148542 -56.48823209 -21.63809162]
# Marker Rotation (Euler angles in degrees): [ 99.95483289 -56.48006155 -21.63664001]
# Marker Rotation (Euler angles in degrees): [ 99.91421924 -56.4266873  -21.58150497]
# Marker Rotation (Euler angles in degrees): [100.04707206 -56.60458503 -21.7711214 ]
# Marker Rotation (Euler angles in degrees): [100.06556284 -56.44307821 -21.83774528]
# Marker Rotation (Euler angles in degrees): [100.22652903 -56.55388487 -21.98869097]
# Marker Rotation (Euler angles in degrees): [149.91760945 -54.27034725 -64.88546817]
# Marker Rotation (Euler angles in degrees): [100.03267111 -56.26668268 -21.68588699]
# Marker Rotation (Euler angles in degrees): [ 99.97229707 -56.30045919 -21.67787828]
# Marker Rotation (Euler angles in degrees): [ 99.90113941 -56.00203903 -21.58831021]
# Marker Rotation (Euler angles in degrees): [ 99.82576039 -55.844605   -21.50505962]
# Marker Rotation (Euler angles in degrees): [ 99.80582051 -56.03548874 -21.40240616]
# Marker Rotation (Euler angles in degrees): [ 99.76918751 -55.78704234 -21.35078891]
# Marker Rotation (Euler angles in degrees): [ 99.8562914  -55.88409395 -21.47232436]
# Marker Rotation (Euler angles in degrees): [ 99.8057908  -55.81654432 -21.37779023]
# Marker Rotation (Euler angles in degrees): [ 99.77506761 -55.87197914 -21.39480528]
# Marker Rotation (Euler angles in degrees): [ 99.70022736 -55.71285079 -21.31187834]
# Marker Rotation (Euler angles in degrees): [ 99.71647625 -55.75831002 -21.24804467]
# Marker Rotation (Euler angles in degrees): [ 99.74319748 -55.57301757 -21.3528255 ]
# Marker Rotation (Euler angles in degrees): [ 99.71197444 -55.64600523 -21.39362621]
# Marker Rotation (Euler angles in degrees): [ 99.79240365 -55.59394832 -21.45615807]
# Marker Rotation (Euler angles in degrees): [ 99.74855574 -55.67484431 -21.42034295]
# Marker Rotation (Euler angles in degrees): [ 99.70376179 -55.61716478 -21.32940986]
# Marker Rotation (Euler angles in degrees): [ 99.84605768 -55.71521656 -21.45547856]
# Marker Rotation (Euler angles in degrees): [ 99.68555186 -55.45783592 -21.25242363]
# Marker Rotation (Euler angles in degrees): [ 99.76661966 -55.4250667  -21.34012646]
# Marker Rotation (Euler angles in degrees): [ 99.69467778 -55.26828763 -21.2590427 ]
# Marker Rotation (Euler angles in degrees): [ 99.56068323 -55.16228785 -21.19380828]
# Marker Rotation (Euler angles in degrees): [ 99.52476382 -55.05039544 -21.16341372]
# Marker Rotation (Euler angles in degrees): [ 99.58682    -54.85394753 -21.09477838]
# Marker Rotation (Euler angles in degrees): [ 99.53018132 -54.69446531 -21.09145546]
# Marker Rotation (Euler angles in degrees): [ 99.51111607 -54.43947605 -21.1070882 ]
# Marker Rotation (Euler angles in degrees): [ 99.41447154 -54.19723293 -21.02758618]
# Marker Rotation (Euler angles in degrees): [ 99.30097974 -54.10853489 -20.88915649]
# Marker Rotation (Euler angles in degrees): [ 99.28411394 -53.95430217 -20.72487064]
# Marker Rotation (Euler angles in degrees): [ 99.3097696  -53.77348532 -20.83257216]
# Marker Rotation (Euler angles in degrees): [ 99.16644262 -53.70393848 -20.7095079 ]
# Marker Rotation (Euler angles in degrees): [ 99.13120726 -53.37741233 -20.74539093]
# Marker Rotation (Euler angles in degrees): [ 99.18833122 -53.51342198 -20.77854995]
# Marker Rotation (Euler angles in degrees): [ 99.04899822 -53.39797321 -20.62069712]
# Marker Rotation (Euler angles in degrees): [ 99.15829817 -53.51672579 -20.82951519]
# Marker Rotation (Euler angles in degrees): [ 99.19114123 -53.49626923 -20.75455229]
# Marker Rotation (Euler angles in degrees): [ 99.30937349 -53.4796486  -20.95548473]
# Marker Rotation (Euler angles in degrees): [ 99.34106254 -53.49497304 -20.97577512]
# Marker Rotation (Euler angles in degrees): [ 99.32237902 -53.65605295 -20.93789047]
# Marker Rotation (Euler angles in degrees): [ 99.35178404 -53.6899727  -20.98280374]
# Marker Rotation (Euler angles in degrees): [ 99.42952384 -53.80534461 -21.10579533]
# Marker Rotation (Euler angles in degrees): [ 99.27920468 -53.86356383 -21.00544918]
# Marker Rotation (Euler angles in degrees): [ 99.32513336 -53.96187398 -21.1077802 ]
# Marker Rotation (Euler angles in degrees): [ 99.30628059 -54.27333997 -21.122978  ]
# Marker Rotation (Euler angles in degrees): [ 99.27535423 -54.43800928 -21.16766615]
# Marker Rotation (Euler angles in degrees): [ 99.33909855 -54.56943753 -21.21902642]
# Marker Rotation (Euler angles in degrees): [ 99.48775747 -55.00478626 -21.46743031]
# Marker Rotation (Euler angles in degrees): [141.32895682 -51.8694052  -57.7829654 ]
# Marker Rotation (Euler angles in degrees): [ 99.59178152 -55.42190975 -21.62211243]
# Marker Rotation (Euler angles in degrees): [143.96348726 -52.88386722 -60.20680101]
# Marker Rotation (Euler angles in degrees): [144.98245913 -53.29969813 -61.17691239]
# Marker Rotation (Euler angles in degrees): [147.01893672 -53.87367083 -63.00874901]
# Marker Rotation (Euler angles in degrees): [148.17772851 -54.41864301 -63.87926317]
# Marker Rotation (Euler angles in degrees): [148.95258587 -54.9969027  -64.75906226]
# Marker Rotation (Euler angles in degrees): [150.60291975 -55.41613131 -66.10848353]
# Marker Rotation (Euler angles in degrees): [151.87571947 -55.85491364 -67.47055443]
# Marker Rotation (Euler angles in degrees): [153.4936832  -55.78484462 -68.73277541]
# Marker Rotation (Euler angles in degrees): [154.09394454 -55.82989885 -69.07599113]
# Marker Rotation (Euler angles in degrees): [154.79132022 -56.73775148 -69.81953124]
# Marker Rotation (Euler angles in degrees): [154.77625881 -57.22037258 -70.20920182]
# Marker Rotation (Euler angles in degrees): [157.28551831 -57.43560842 -72.35623194]
# Marker Rotation (Euler angles in degrees): [158.01162589 -57.28626744 -73.01598572]
# Marker Rotation (Euler angles in degrees): [160.116614   -57.02097334 -74.71510288]
# Marker Rotation (Euler angles in degrees): [160.50770352 -56.71146275 -75.28107423]
# Marker Rotation (Euler angles in degrees): [160.59984244 -57.06264375 -75.28290113]
# Marker Rotation (Euler angles in degrees): [159.73411479 -56.30077429 -74.86393688]
# Marker Rotation (Euler angles in degrees): [160.3504084  -56.52147379 -75.34442028]
# Marker Rotation (Euler angles in degrees): [162.28492017 -57.00603025 -76.74347914]
# Marker Rotation (Euler angles in degrees): [161.74160254 -57.13868761 -76.24898671]
# Marker Rotation (Euler angles in degrees): [160.88668021 -57.12727476 -75.68946311]
# Marker Rotation (Euler angles in degrees): [159.86078468 -57.2012543  -74.61859331]
# Marker Rotation (Euler angles in degrees): [159.87086002 -57.20392481 -74.62559076]
# Marker Rotation (Euler angles in degrees): [160.79317031 -57.50271122 -75.53948468]
# Marker Rotation (Euler angles in degrees): [161.2716246  -57.08761379 -75.68440087]
# Marker Rotation (Euler angles in degrees): [161.03817774 -57.2953702  -75.61689915]
# Marker Rotation (Euler angles in degrees): [160.4129178  -57.07334011 -75.12153111]
# Marker Rotation (Euler angles in degrees): [160.31999703 -57.45434842 -74.97093336]
# Marker Rotation (Euler angles in degrees): [161.96309821 -57.58855319 -76.53557579]
# Marker Rotation (Euler angles in degrees): [161.57615664 -57.16125158 -76.10807305]
# Marker Rotation (Euler angles in degrees): [161.03199281 -57.29052541 -75.61090682]
# Marker Rotation (Euler angles in degrees): [160.40680731 -57.06844678 -75.11565303]
# Marker Rotation (Euler angles in degrees): [161.03199281 -57.29052541 -75.61090682]
# Marker Rotation (Euler angles in degrees): [160.79376834 -57.49439489 -75.53702024]
# Marker Rotation (Euler angles in degrees): [160.79376834 -57.49439489 -75.53702024]
# Marker Rotation (Euler angles in degrees): [162.04380674 -57.19716052 -76.66718212]
# Marker Rotation (Euler angles in degrees): [162.04380674 -57.19716052 -76.66718212]
# Marker Rotation (Euler angles in degrees): [161.56986341 -57.15641845 -76.10201724]
# Marker Rotation (Euler angles in degrees): [160.0225099  -57.10137476 -75.11842207]
# Marker Rotation (Euler angles in degrees): [160.88134219 -57.1140159  -75.68121935]
# Marker Rotation (Euler angles in degrees): [161.75090097 -57.13153067 -76.25310194]
# Marker Rotation (Euler angles in degrees): [161.58711849 -56.95188495 -76.31262848]
# Marker Rotation (Euler angles in degrees): [162.12652431 -56.81733858 -76.80457291]
# Marker Rotation (Euler angles in degrees): [161.82073383 -56.74665012 -76.38115813]
# Marker Rotation (Euler angles in degrees): [161.5802871  -56.95542799 -76.30911898]
# Marker Rotation (Euler angles in degrees): [160.04673307 -56.43986941 -74.92102523]
# Marker Rotation (Euler angles in degrees): [160.80703597 -56.84271588 -75.33045023]
# Marker Rotation (Euler angles in degrees): [160.27843139 -56.2387646  -74.99212401]
# Marker Rotation (Euler angles in degrees): [161.26579023 -56.14945362 -76.02290909]
# Marker Rotation (Euler angles in degrees): [160.3614957  -55.85554342 -75.13640139]
# Marker Rotation (Euler angles in degrees): [160.59776651 -55.6474718  -75.20883328]
# Marker Rotation (Euler angles in degrees): [159.98567273 -56.16872047 -74.58583524]
# Marker Rotation (Euler angles in degrees): [158.99512976 -55.49496223 -73.70717508]
# Marker Rotation (Euler angles in degrees): [159.36987507 -55.94361996 -74.10794929]
# Marker Rotation (Euler angles in degrees): [158.49212071 -55.6385599  -73.24795629]
# Marker Rotation (Euler angles in degrees): [159.1052081  -55.87331134 -73.72237643]
# Marker Rotation (Euler angles in degrees): [158.49212071 -55.6385599  -73.24795629]
# Marker Rotation (Euler angles in degrees): [158.25513802 -55.84760651 -73.17139578]
# Marker Rotation (Euler angles in degrees): [156.96278671 -56.29750992 -71.79207206]
# Marker Rotation (Euler angles in degrees): [100.69176282 -57.61769542 -23.3239558 ]
# Marker Rotation (Euler angles in degrees): [154.4893747  -56.79433391 -69.51905428]
# Marker Rotation (Euler angles in degrees): [100.23822135 -57.39617412 -22.86970952]
# Marker Rotation (Euler angles in degrees): [100.07806014 -57.4824395  -22.70234694]
# Marker Rotation (Euler angles in degrees): [ 99.89952345 -57.57517975 -22.45113208]
# Marker Rotation (Euler angles in degrees): [153.02220234 -58.19412561 -68.06028182]
# Marker Rotation (Euler angles in degrees): [152.07772141 -58.66563787 -67.10094562]
# Marker Rotation (Euler angles in degrees): [ 99.47009131 -57.75941974 -21.77139493]
# Marker Rotation (Euler angles in degrees): [ 99.29203155 -57.66543864 -21.54496969]
# Marker Rotation (Euler angles in degrees): [ 99.0957221  -57.77527632 -21.21856727]
# Marker Rotation (Euler angles in degrees): [150.12860453 -60.21228762 -65.30810595]
# Marker Rotation (Euler angles in degrees): [ 98.91358653 -57.86415255 -20.9641077 ]
# Marker Rotation (Euler angles in degrees): [151.29291007 -60.38535341 -66.33404844]
# Marker Rotation (Euler angles in degrees): [151.29291007 -60.38535341 -66.33404844]
# Marker Rotation (Euler angles in degrees): [ 99.03547374 -57.64263176 -21.19550747]
# Marker Rotation (Euler angles in degrees): [ 99.03757811 -57.79000032 -21.22165484]
# Marker Rotation (Euler angles in degrees): [149.43901925 -59.80663951 -64.94827231]
# Marker Rotation (Euler angles in degrees): [151.29291007 -60.38535341 -66.33404844]
# Marker Rotation (Euler angles in degrees): [149.90549184 -60.40058047 -64.88669996]
# Marker Rotation (Euler angles in degrees): [149.1460401  -61.27513106 -64.14970393]
# Marker Rotation (Euler angles in degrees): [147.46527513 -61.7448952  -62.46554477]
# Marker Rotation (Euler angles in degrees): [147.1626323  -62.56274133 -62.17001532]
# Marker Rotation (Euler angles in degrees): [145.94098298 -62.9801944  -60.92493184]
# Marker Rotation (Euler angles in degrees): [145.30530808 -63.63644144 -60.16968431]
# Marker Rotation (Euler angles in degrees): [ 97.10491203 -57.9536057  -18.51738438]
# Marker Rotation (Euler angles in degrees): [ 96.84711117 -57.8959045  -18.1996566 ]
# Marker Rotation (Euler angles in degrees): [141.59497082 -65.33075008 -56.57014811]
# Marker Rotation (Euler angles in degrees): [141.22205407 -66.17840141 -55.65144534]
# Marker Rotation (Euler angles in degrees): [ 96.57934962 -57.67969705 -17.91637852]
# Marker Rotation (Euler angles in degrees): [-124.67958588  -83.29690864 -168.71940799]
# Marker Rotation (Euler angles in degrees): [ 96.54606903 -57.81762892 -17.80818017]
# Marker Rotation (Euler angles in degrees): [ 96.55476575 -57.83541012 -17.77707326]
# Marker Rotation (Euler angles in degrees): [ 96.80494693 -57.73417002 -18.04101338]
# Marker Rotation (Euler angles in degrees): [142.86008029 -64.32339321 -57.30073938]
# Marker Rotation (Euler angles in degrees): [ 96.76065287 -57.66617468 -17.9323454 ]
# Marker Rotation (Euler angles in degrees): [142.41891879 -65.23545837 -57.01101883]
# Marker Rotation (Euler angles in degrees): [ 96.58591617 -57.53345369 -17.76240835]
# Marker Rotation (Euler angles in degrees): [ 96.55139624 -57.56197477 -17.65917903]
# Marker Rotation (Euler angles in degrees): [-123.05528559  -83.45965011 -169.88824069]
# Marker Rotation (Euler angles in degrees): [136.96035905 -66.51483902 -51.39978456]
# Marker Rotation (Euler angles in degrees): [137.02908939 -67.21982829 -51.13658067]
# Marker Rotation (Euler angles in degrees): [-120.93694711  -83.70166263 -172.30107911]
# Marker Rotation (Euler angles in degrees): [135.56924014 -67.30404929 -49.15561932]
# Marker Rotation (Euler angles in degrees): [135.33790322 -67.88391082 -49.1499834 ]
# Marker Rotation (Euler angles in degrees): [ 95.60090535 -57.4919283  -16.54532335]
# Marker Rotation (Euler angles in degrees): [ 95.69126077 -57.6836179  -16.64033248]
# Marker Rotation (Euler angles in degrees): [135.90273032 -67.14560483 -50.03399208]
# Marker Rotation (Euler angles in degrees): [-121.29431395  -83.61319791 -171.90964206]
# Marker Rotation (Euler angles in degrees): [ 91.17741488 -44.77785564 -17.20576512]
# Marker Rotation (Euler angles in degrees): [133.65622234 -68.05268812 -47.4422345 ]
# Marker Rotation (Euler angles in degrees): [ 95.51825699 -57.89943766 -16.63035088]
# Marker Rotation (Euler angles in degrees): [ 95.3738517  -57.96054615 -16.94422089]
# Marker Rotation (Euler angles in degrees): [ 90.73386414 -44.53770003 -18.33673429]
# Marker Rotation (Euler angles in degrees): [ 94.57241888 -57.9045802  -15.95371651]
# Marker Rotation (Euler angles in degrees): [ 94.33003094 -58.16445502 -15.62999476]
# Marker Rotation (Euler angles in degrees): [ 93.2253832  -46.81015596 -17.98032396]
# Marker Rotation (Euler angles in degrees): [ -94.1461496   -46.87354083 -139.43360404]
# Marker Rotation (Euler angles in degrees): [ -94.28171715  -47.03226966 -141.14855701]
# Marker Rotation (Euler angles in degrees): [170.28366174 -70.47468559 -78.3547607 ]
# Marker Rotation (Euler angles in degrees): [ -94.61819924  -47.17965615 -137.49183503]
# Marker Rotation (Euler angles in degrees): [ 97.68905523 -58.36257608 -17.57543517]
# Marker Rotation (Euler angles in degrees): [ 93.55527533 -46.69820121 -27.05437939]
# Marker Rotation (Euler angles in degrees): [ 93.71890138 -46.76771275 -27.50059478]
# Marker Rotation (Euler angles in degrees): [175.30297413 -68.28147286 -83.53674681]
# Marker Rotation (Euler angles in degrees): [ 93.74687719 -46.87870715 -28.36423276]
# Marker Rotation (Euler angles in degrees): [ 93.83264133 -46.85907792 -29.79117449]
# Marker Rotation (Euler angles in degrees): [ 93.86417597 -46.88710044 -30.45569162]
# Marker Rotation (Euler angles in degrees): [ 93.98766447 -46.82943714 -31.56316911]
# Marker Rotation (Euler angles in degrees): [ 94.06314224 -46.91388438 -30.8824636 ]
# Marker Rotation (Euler angles in degrees): [ 94.13067931 -46.90415003 -31.41784025]
# Marker Rotation (Euler angles in degrees): [ 94.13582778 -46.90678472 -32.38059731]
# Marker Rotation (Euler angles in degrees): [ 94.14245059 -46.9073885  -32.35682135]
# Marker Rotation (Euler angles in degrees): [ 94.19101475 -46.9323816  -32.6437366 ]
# Marker Rotation (Euler angles in degrees): [ 94.15742257 -46.93252848 -33.09819923]
# Marker Rotation (Euler angles in degrees): [-176.47087443  -68.45785378  -92.75633949]
# Marker Rotation (Euler angles in degrees): [ -94.19754696  -47.31937895 -147.76672366]
# Marker Rotation (Euler angles in degrees): [-174.50365491  -68.51033347  -94.59113373]
# Marker Rotation (Euler angles in degrees): [-174.87501615  -68.62611013  -93.97465966]
# Marker Rotation (Euler angles in degrees): [-175.54906656  -68.73457875  -93.3588228 ]
# Marker Rotation (Euler angles in degrees): [-176.55725785  -68.35316433  -92.69500391]
# Marker Rotation (Euler angles in degrees): [-176.6812646   -68.2104093   -92.71990972]
# Marker Rotation (Euler angles in degrees): [ 97.92322002 -58.74141348 -18.25824077]
# Marker Rotation (Euler angles in degrees): [-179.30994009  -68.43222845  -90.29586937]
# Marker Rotation (Euler angles in degrees): [ 94.04030521 -46.96689233 -30.29806465]
# Marker Rotation (Euler angles in degrees): [178.27172108 -67.78842844 -87.91516581]
# Marker Rotation (Euler angles in degrees): [178.58776789 -67.98716539 -87.93305601]
# Marker Rotation (Euler angles in degrees): [ 94.00900159 -46.82135639 -30.93948383]
# Marker Rotation (Euler angles in degrees): [177.94004807 -68.19702995 -87.32848835]
# Marker Rotation (Euler angles in degrees): [178.24001812 -68.19928702 -87.3263329 ]
# Marker Rotation (Euler angles in degrees): [178.24001812 -68.19928702 -87.3263329 ]
# Marker Rotation (Euler angles in degrees): [ 93.84576942 -47.372438   -23.18427751]
# Marker Rotation (Euler angles in degrees): [178.22570234 -68.19486936 -87.31300017]
# Marker Rotation (Euler angles in degrees): [178.22816774 -68.0036466  -87.30609042]
# Marker Rotation (Euler angles in degrees): [ 93.99407462 -46.79282166 -31.08787184]
# Marker Rotation (Euler angles in degrees): [ 98.0199943  -58.70106233 -18.352625  ]
# Marker Rotation (Euler angles in degrees): [-179.82651607  -68.42519868  -89.11239341]
# Marker Rotation (Euler angles in degrees): [178.82343894 -68.40713633 -87.86056686]
# Marker Rotation (Euler angles in degrees): [179.84626371 -68.72440619 -89.09136042]
# Marker Rotation (Euler angles in degrees): [-179.99415155  -68.57227117  -89.09816363]
# Marker Rotation (Euler angles in degrees): [ 94.0529516  -46.78300474 -32.22446299]
# Marker Rotation (Euler angles in degrees): [ 93.95167254 -46.94724778 -29.83380027]
# Marker Rotation (Euler angles in degrees): [179.50070266 -68.32110257 -88.48289108]
# Marker Rotation (Euler angles in degrees): [ 93.92291343 -47.04406186 -28.09978197]
# Marker Rotation (Euler angles in degrees): [178.78126022 -68.70898944 -87.82057157]
# Marker Rotation (Euler angles in degrees): [-179.8431929   -68.23477255  -89.08822546]
# Marker Rotation (Euler angles in degrees): [179.84590317 -68.23549805 -89.08699512]
# Marker Rotation (Euler angles in degrees): [-179.85011837  -68.23841289  -89.08495999]
# Marker Rotation (Euler angles in degrees): [179.83897259 -68.23915573 -89.08372584]
# Marker Rotation (Euler angles in degrees): [179.83897259 -68.23915573 -89.08372584]
# Marker Rotation (Euler angles in degrees): [ 93.89680779 -46.97160837 -28.98466315]
# Marker Rotation (Euler angles in degrees): [179.1581729  -68.63704411 -88.45722559]
# Marker Rotation (Euler angles in degrees): [179.51727159 -68.54988898 -89.07316212]
# Marker Rotation (Euler angles in degrees): [ 93.9192285  -46.84856594 -30.53029656]
# Marker Rotation (Euler angles in degrees): [179.15115368 -68.64068465 -88.45385263]
# Marker Rotation (Euler angles in degrees): [-179.66755753  -68.80473956  -89.69646728]
# Marker Rotation (Euler angles in degrees): [ 94.17265656 -46.82501186 -32.25448683]
# Marker Rotation (Euler angles in degrees): [ -94.323667    -47.32402149 -145.99855514]
# Marker Rotation (Euler angles in degrees): [179.80678869 -68.55944735 -89.06458919]
# Marker Rotation (Euler angles in degrees): [179.49650409 -68.56094727 -89.0633311 ]
# Marker Rotation (Euler angles in degrees): [ 93.90257508 -46.71584285 -32.27474183]
# Marker Rotation (Euler angles in degrees): [ 93.90257508 -46.71584285 -32.27474183]
# Marker Rotation (Euler angles in degrees): [ 93.95058069 -46.98350688 -30.53769808]
# Marker Rotation (Euler angles in degrees): [ 93.96685786 -46.8250711  -32.87032703]
# Marker Rotation (Euler angles in degrees): [ 94.20550187 -46.8479364  -33.73982027]
# Marker Rotation (Euler angles in degrees): [ 94.1446763  -46.84412624 -33.66681306]
# Marker Rotation (Euler angles in degrees): [ 94.0315068  -46.80876739 -33.42733385]
# Marker Rotation (Euler angles in degrees): [ 94.50531416 -47.00759836 -32.06909789]
# Marker Rotation (Euler angles in degrees): [ 93.97207523 -46.90124255 -32.53031772]
# Marker Rotation (Euler angles in degrees): [ 93.95515126 -46.91725171 -32.90180847]
# Marker Rotation (Euler angles in degrees): [ 93.94865348 -46.9572091  -32.09273228]
# Marker Rotation (Euler angles in degrees): [ 93.93393503 -46.90741038 -32.90280778]
# Marker Rotation (Euler angles in degrees): [ 93.87817279 -46.9210135  -32.4781087 ]
# Marker Rotation (Euler angles in degrees): [ 93.87869993 -46.97146386 -32.40844439]
# Marker Rotation (Euler angles in degrees): [ 93.84954428 -47.01315155 -31.93059855]
# Marker Rotation (Euler angles in degrees): [ 93.85799185 -46.98482018 -32.87232822]
# Marker Rotation (Euler angles in degrees): [ 93.73969612 -47.28564896 -28.58645347]
# Marker Rotation (Euler angles in degrees): [ 93.85799185 -46.98482018 -32.87232822]
# Marker Rotation (Euler angles in degrees): [ 93.88189438 -47.02646779 -32.72270358]
# Marker Rotation (Euler angles in degrees): [ 93.84863793 -47.01884362 -32.34042035]
# Marker Rotation (Euler angles in degrees): [ 93.83552441 -47.01151986 -32.61618975]
# Marker Rotation (Euler angles in degrees): [ 93.81734633 -46.98781742 -32.29655638]
# Marker Rotation (Euler angles in degrees): [ 93.80802561 -47.06453434 -31.41733755]
# Marker Rotation (Euler angles in degrees): [ 93.71645418 -47.21025756 -29.62442626]
# Marker Rotation (Euler angles in degrees): [ 93.71281985 -47.12674539 -30.84870334]
# Marker Rotation (Euler angles in degrees): [-178.78423517  -71.95177524  -91.10318612]
# Marker Rotation (Euler angles in degrees): [ 93.84647639 -47.01907408 -32.87726011]
# Marker Rotation (Euler angles in degrees): [ 93.63778972 -47.17094633 -30.02220653]
# Marker Rotation (Euler angles in degrees): [ 94.59599572 -47.41214474 -28.99901728]
# Marker Rotation (Euler angles in degrees): [179.70515045 -72.25869318 -89.67130874]
# Marker Rotation (Euler angles in degrees): [ 93.5452086  -47.2537754  -28.80674812]
# Marker Rotation (Euler angles in degrees): [ 93.47512957 -47.62874982 -23.83200686]
# Marker Rotation (Euler angles in degrees): [ 93.59003595 -47.08170963 -31.14514938]
# Marker Rotation (Euler angles in degrees): [ 93.55446349 -47.09787559 -31.00796353]
# Marker Rotation (Euler angles in degrees): [ 94.16402887 -47.24258779 -30.48846806]
# Marker Rotation (Euler angles in degrees): [ 94.16402887 -47.24258779 -30.48846806]
# Marker Rotation (Euler angles in degrees): [ 93.60625267 -47.0153444  -31.56663665]
# Marker Rotation (Euler angles in degrees): [ 93.39172359 -47.43439122 -26.26370357]
# Marker Rotation (Euler angles in degrees): [ 94.41363641 -47.34444033 -29.61724407]
# Marker Rotation (Euler angles in degrees): [ 93.6262325  -47.06990685 -31.31284283]
# Marker Rotation (Euler angles in degrees): [ 93.59442732 -47.03368183 -32.15605114]
# Marker Rotation (Euler angles in degrees): [ 93.83087022 -47.0919529  -32.22501656]
# Marker Rotation (Euler angles in degrees): [ 93.61547347 -47.06110457 -31.70067529]
# Marker Rotation (Euler angles in degrees): [ 93.61547347 -47.06110457 -31.70067529]
# Marker Rotation (Euler angles in degrees): [ 93.56156034 -47.25751163 -29.51589931]
# Marker Rotation (Euler angles in degrees): [ 93.62187713 -47.07013689 -31.6561722 ]
# Marker Rotation (Euler angles in degrees): [-179.3411044   -71.96041887  -91.13857867]
# Marker Rotation (Euler angles in degrees): [-178.21372456  -72.17819092  -91.92759559]
# Marker Rotation (Euler angles in degrees): [ 93.61377354 -46.99107278 -32.23043662]
# Marker Rotation (Euler angles in degrees): [ 93.52665997 -47.29112178 -28.17968197]
# Marker Rotation (Euler angles in degrees): [ 93.45822648 -47.4630677  -25.36089149]
# Marker Rotation (Euler angles in degrees): [-179.39738137  -72.78749528  -90.52056865]
# Marker Rotation (Euler angles in degrees): [178.96956903 -72.78313956 -88.96438634]
# Marker Rotation (Euler angles in degrees): [179.01355359 -72.93420221 -89.00858328]
# Marker Rotation (Euler angles in degrees): [ -93.65557525  -48.00554122 -153.13209709]
# ...
# Marker Rotation (Euler angles in degrees): [-150.64681058  -52.24378391 -111.27902278]
# Marker Rotation (Euler angles in degrees): [-150.08344669  -52.00578856 -111.69042548]
# Marker Rotation (Euler angles in degrees): [-149.9495167   -51.85545039 -111.59232906]
# Marker Rotation (Euler angles in degrees): [-149.77279548  -51.55015262 -111.98935304]
# Marker Rotation (Euler angles in degrees): [-150.02682502  -51.34151696 -111.88233089]
# Marker Rotation (Euler angles in degrees): [-149.70625714  -50.87995927 -112.18251386]
# Marker Rotation (Euler angles in degrees): [-149.55295468  -50.47870195 -112.17062506]
# Marker Rotation (Euler angles in degrees): [-149.55836323  -50.48123697 -112.16816249]
# Marker Rotation (Euler angles in degrees): [-149.78410685  -50.01269507 -112.16502489]
# Marker Rotation (Euler angles in degrees): [-149.62498621  -49.95291877 -112.47459595]
# Marker Rotation (Euler angles in degrees): [-150.00693161  -49.98717664 -112.87771787]
# Marker Rotation (Euler angles in degrees): [-149.9968613   -50.08028479 -113.27773565]
# Marker Rotation (Euler angles in degrees): [-149.55473285  -49.44790164 -113.45933399]
# Marker Rotation (Euler angles in degrees): [-149.94830822  -49.39230695 -113.4641353 ]
# Marker Rotation (Euler angles in degrees): [-150.18945881  -49.17637122 -113.37132445]
# Marker Rotation (Euler angles in degrees): [ 151.11643471   49.84776465 -113.05620657]
# Marker Rotation (Euler angles in degrees): [ 151.53266152   49.78924846 -113.04482196]
# Marker Rotation (Euler angles in degrees): [-150.12487431  -48.57926637 -113.95519167]
# Marker Rotation (Euler angles in degrees): [-151.21915432  -49.12248761 -113.2012948 ]
# Marker Rotation (Euler angles in degrees): [-150.92117083  -48.644471   -113.48674635]
# Marker Rotation (Euler angles in degrees): [ 152.26731011   49.7841294  -112.79356274]
# Marker Rotation (Euler angles in degrees): [-150.76771501  -48.58989876 -113.77498955]
# Marker Rotation (Euler angles in degrees): [-151.19197407  -49.33829639 -113.98923017]
# Marker Rotation (Euler angles in degrees): [-150.92193873  -49.65152079 -114.4811069 ]
# Marker Rotation (Euler angles in degrees): [-151.29931034  -48.96893245 -113.7894207 ]
# Marker Rotation (Euler angles in degrees): [-151.29625122  -48.97318515 -113.79618158]
# Marker Rotation (Euler angles in degrees): [-150.90309329  -48.86810592 -114.27476723]
# Marker Rotation (Euler angles in degrees): [-150.89454816  -49.1293868  -114.17609018]
# Marker Rotation (Euler angles in degrees): [-151.03042316  -49.28924307 -114.28331417]
# Marker Rotation (Euler angles in degrees): [-151.29383309  -49.86470544 -114.39371161]
# Marker Rotation (Euler angles in degrees): [-151.28323503  -49.08261077 -114.18240269]
# Marker Rotation (Euler angles in degrees): [-152.09497133  -49.82897095 -113.53724382]
# Marker Rotation (Euler angles in degrees): [-151.81711071  -49.35296655 -113.81068857]
# Marker Rotation (Euler angles in degrees): [-151.12906931  -49.02040877 -114.45817614]
# Marker Rotation (Euler angles in degrees): [-151.41039883  -49.50452999 -114.19082369]
# Marker Rotation (Euler angles in degrees): [-151.01549757  -49.39048815 -114.66771308]
# Marker Rotation (Euler angles in degrees): [-151.70259883  -49.73009958 -114.01829282]
# Marker Rotation (Euler angles in degrees): [-151.82513933  -49.35240404 -113.80239632]
# Marker Rotation (Euler angles in degrees): [-151.8376342   -49.25724647 -113.42805508]
# Marker Rotation (Euler angles in degrees): [-151.82167815  -49.35674363 -113.80939499]
# Marker Rotation (Euler angles in degrees): [-151.55036459  -49.67239771 -114.29755409]
# Marker Rotation (Euler angles in degrees): [-152.49267459  -49.79697863 -113.54214269]
# Marker Rotation (Euler angles in degrees): [-152.32524792  -49.73143954 -113.82589672]
# Marker Rotation (Euler angles in degrees): [-152.06160287  -49.15372307 -113.72465278]
# Marker Rotation (Euler angles in degrees): [-152.32001151  -49.74041732 -113.83415433]
# Marker Rotation (Euler angles in degrees): [-151.79488927  -49.46832378 -114.20394636]
# Marker Rotation (Euler angles in degrees): [-152.32749027  -49.7334181  -113.82531695]
# Marker Rotation (Euler angles in degrees): [-152.07941838  -49.94079761 -113.92489739]
# Marker Rotation (Euler angles in degrees): [-151.95787949  -50.30678447 -114.133934  ]
# Marker Rotation (Euler angles in degrees): [-151.9420479   -50.31379089 -114.15127935]
# Marker Rotation (Euler angles in degrees): [-152.99440053  -50.84522731 -113.39714014]
# Marker Rotation (Euler angles in degrees): [-153.51001282  -51.63910633 -113.33782584]
# Marker Rotation (Euler angles in degrees): [-154.20562011  -51.31014068 -112.84114281]
# Marker Rotation (Euler angles in degrees): [-156.46122124  -52.5218192  -111.3716945 ]
# Marker Rotation (Euler angles in degrees): [-157.96236392  -52.80919558 -110.67104089]
# Marker Rotation (Euler angles in degrees): [-159.76516433  -52.99654666 -109.35539757]
# Marker Rotation (Euler angles in degrees): [-161.56572978  -53.09257947 -108.53261711]
# Marker Rotation (Euler angles in degrees): [-162.73921477  -53.40321405 -107.78186653]
# Marker Rotation (Euler angles in degrees): [-164.5652636   -53.19730257 -106.42293488]
# Marker Rotation (Euler angles in degrees): [-165.48811484  -53.44688202 -106.0113085 ]
# Marker Rotation (Euler angles in degrees): [-166.27176256  -53.11627574 -105.50462054]
# Marker Rotation (Euler angles in degrees): [-166.98604354  -53.16444123 -105.11552701]
# Marker Rotation (Euler angles in degrees): [-166.85400666  -52.91061645 -105.54056064]
# Marker Rotation (Euler angles in degrees): [-167.53119849  -53.36395425 -105.18770771]
# Marker Rotation (Euler angles in degrees): [-168.10504983  -52.81401886 -104.72251453]
# Marker Rotation (Euler angles in degrees): [-168.25471895  -53.01439139 -104.79146725]
# Marker Rotation (Euler angles in degrees): [-168.82276047  -52.86186792 -104.33715402]
# Marker Rotation (Euler angles in degrees): [-169.12414407  -52.9143934  -103.95564411]
# Marker Rotation (Euler angles in degrees): [-169.69690084  -52.76008154 -103.49842836]
# Marker Rotation (Euler angles in degrees): [-170.43748219  -52.80776616 -103.09933558]
# Marker Rotation (Euler angles in degrees): [-170.31880665  -53.21749358 -103.23401979]
# Marker Rotation (Euler angles in degrees): [-171.45757748  -52.9454423  -101.79998776]
# Marker Rotation (Euler angles in degrees): [-170.91167272  -52.6785144  -102.23783674]
# Marker Rotation (Euler angles in degrees): [-172.24872664  -53.65948102 -101.04653162]
# Marker Rotation (Euler angles in degrees): [-172.53617851  -52.639695   -100.45369491]
# Marker Rotation (Euler angles in degrees): [-172.14903967  -52.58563815 -100.95284972]
# Marker Rotation (Euler angles in degrees): [-172.6292739   -52.8780528  -100.06598274]
# Marker Rotation (Euler angles in degrees): [-174.14324789  -52.99446504  -98.69886364]
# Marker Rotation (Euler angles in degrees): [-173.25323061  -52.25157973  -99.57577897]
# Marker Rotation (Euler angles in degrees): [-174.80234545  -52.36468966  -98.19152059]
# Marker Rotation (Euler angles in degrees): [-175.78894845  -52.19642127  -97.25681067]
# Marker Rotation (Euler angles in degrees): [-174.79226255  -50.95093811  -97.70417292]
# Marker Rotation (Euler angles in degrees): [-175.27631343  -51.23961583  -96.78253885]
# Marker Rotation (Euler angles in degrees): [-175.25526503  -50.71670258  -96.83392244]
# Marker Rotation (Euler angles in degrees): [-173.10677089  -50.07453915  -98.31323204]
# Marker Rotation (Euler angles in degrees): [-173.96889398  -49.55753009  -97.85653589]
# Marker Rotation (Euler angles in degrees): [-175.00748549  -48.76306849  -96.88639121]
# Marker Rotation (Euler angles in degrees): [-174.00925366  -48.64332847  -97.47816881]
# Marker Rotation (Euler angles in degrees): [-173.3374409   -47.69912969  -97.96166243]
# Marker Rotation (Euler angles in degrees): [-173.42881327  -46.79109594  -97.45127484]
# Marker Rotation (Euler angles in degrees): [-172.64854903  -46.34924967  -98.03197819]
# Marker Rotation (Euler angles in degrees): [-172.25770366  -45.28184258  -98.05981503]
# Marker Rotation (Euler angles in degrees): [-172.68759698  -44.94499819  -97.07621799]
# Marker Rotation (Euler angles in degrees): [-171.87673402  -43.79423912  -97.57206977]
# Marker Rotation (Euler angles in degrees): [-170.60604426  -43.93396553  -98.73321966]
# Marker Rotation (Euler angles in degrees): [-172.36946726  -41.61429219  -97.0961335 ]
# Marker Rotation (Euler angles in degrees): [-170.58940115  -39.35639622  -97.58228332]
# Marker Rotation (Euler angles in degrees): [-167.93636131  -38.67742174  -99.22168923]
# Marker Rotation (Euler angles in degrees): [-168.63386914  -38.17085076  -98.70204179]
# Marker Rotation (Euler angles in degrees): [-166.77456983  -37.1943066   -99.73205387]
# Marker Rotation (Euler angles in degrees): [-166.2753106   -37.0213906  -100.28801652]
# Marker Rotation (Euler angles in degrees): [-167.94504005  -34.88706986  -98.65691657]
# Marker Rotation (Euler angles in degrees): [-166.92332667  -34.35436131  -99.17172927]
# Marker Rotation (Euler angles in degrees): [-165.13759752  -34.86271568  -99.79864785]
# Marker Rotation (Euler angles in degrees): [ 94.55178882 -43.87188421 -72.3771802 ]
# Marker Rotation (Euler angles in degrees): [ 98.44962964 -59.43648243 -11.15213098]
# Marker Rotation (Euler angles in degrees): [-159.99589718  -33.31462648 -102.52493608]
# Marker Rotation (Euler angles in degrees): [-160.00844383  -31.43266379 -101.98584727]
# Marker Rotation (Euler angles in degrees): [ 94.26695112 -43.71446385 -77.59839958]
# Marker Rotation (Euler angles in degrees): [-160.71774738  -29.45655758 -101.03916925]
# Marker Rotation (Euler angles in degrees): [-157.78850045  -29.39195135 -102.62195568]
# Marker Rotation (Euler angles in degrees): [ 94.26393971 -43.74908485 -77.5115407 ]
# Marker Rotation (Euler angles in degrees): [-156.59649599  -28.99150337 -103.15018663]
# Marker Rotation (Euler angles in degrees): [-157.32245725  -30.1895414  -103.15080292]
# Marker Rotation (Euler angles in degrees): [-158.89049813  -30.96752397 -102.49177819]
# Marker Rotation (Euler angles in degrees): [-162.82550314  -32.68466551 -100.98973956]
# Marker Rotation (Euler angles in degrees): [-163.28234574  -31.01801083 -100.32845987]
# Marker Rotation (Euler angles in degrees): [ 98.27182522 -59.01558482 -11.53540352]
# Marker Rotation (Euler angles in degrees): [ 98.35648015 -59.24154111 -11.65614758]
# Marker Rotation (Euler angles in degrees): [-162.56222158  -32.83768112 -101.45721521]
# Marker Rotation (Euler angles in degrees): [-161.45979594  -32.3603503  -101.98310736]
# Marker Rotation (Euler angles in degrees): [-161.94463307  -33.54182837 -101.99081898]
# Marker Rotation (Euler angles in degrees): [-162.80733144  -33.3297735  -101.9940595 ]
# Marker Rotation (Euler angles in degrees): [-163.49244505  -34.7965823  -101.87795447]
# Marker Rotation (Euler angles in degrees): [ 98.90370054 -60.33565126 -12.44063964]
# Marker Rotation (Euler angles in degrees): [-166.09881184  -35.61228179 -100.68330794]
# Marker Rotation (Euler angles in degrees): [-168.62616271  -37.24743325  -99.61189939]
# Marker Rotation (Euler angles in degrees): [-167.91096138  -37.78103126 -100.13173263]
# Marker Rotation (Euler angles in degrees): [-168.99531976  -39.66572889 -100.15682082]
# Marker Rotation (Euler angles in degrees): [-169.49056276  -40.20703273 -100.11571858]
# Marker Rotation (Euler angles in degrees): [-171.24149032  -41.32364818  -99.0146604 ]
# Marker Rotation (Euler angles in degrees): [-172.82332354  -41.9290326   -98.42124267]
# Marker Rotation (Euler angles in degrees): [-171.65468375  -43.01299846  -99.51056353]
# Marker Rotation (Euler angles in degrees): [-172.20169667  -43.26455279  -98.8699488 ]
# Marker Rotation (Euler angles in degrees): [-173.34767723  -44.2407773   -98.27433057]
# Marker Rotation (Euler angles in degrees): [-173.46845671  -45.95806259  -99.24969621]
# Marker Rotation (Euler angles in degrees): [-174.39493355  -47.32943638  -98.75326149]
# Marker Rotation (Euler angles in degrees): [-177.04151322  -49.04692827  -96.30229837]
# Marker Rotation (Euler angles in degrees): [-175.60171497  -49.80423244  -97.7062343 ]
# Marker Rotation (Euler angles in degrees): [-176.42674198  -50.38905152  -97.22007776]
# Marker Rotation (Euler angles in degrees): [-177.32693329  -51.22362557  -96.28189927]
# Marker Rotation (Euler angles in degrees): [-176.21954233  -51.14936849  -97.66822564]
# Marker Rotation (Euler angles in degrees): [-175.9734295   -51.39729282  -97.65058844]
# Marker Rotation (Euler angles in degrees): [-177.30752861  -52.17914508  -96.76644025]
# Marker Rotation (Euler angles in degrees): [-175.93083816  -52.3120248   -98.19295441]
# Marker Rotation (Euler angles in degrees): [-176.19121015  -52.10110735  -98.1535925 ]
# Marker Rotation (Euler angles in degrees): [-176.38026205  -51.90114418  -97.67255676]
# Marker Rotation (Euler angles in degrees): [-176.02316332  -51.88230623  -98.10795338]
# Marker Rotation (Euler angles in degrees): [-175.02552879  -52.01842617  -99.07789426]
# Marker Rotation (Euler angles in degrees): [-176.20956121  -52.10699845  -98.14643485]
# Marker Rotation (Euler angles in degrees): [-175.01736588  -52.02861004  -99.08639548]
# Marker Rotation (Euler angles in degrees): [-175.01736588  -52.02861004  -99.08639548]
# Marker Rotation (Euler angles in degrees): [-175.85496155  -52.08589328  -98.57763341]
# Marker Rotation (Euler angles in degrees): [-176.5266058   -53.01863244  -98.17808343]
# Marker Rotation (Euler angles in degrees): [-175.0022521   -52.48953728  -99.02815794]
# Marker Rotation (Euler angles in degrees): [-175.82807093  -52.5453801   -98.52351017]
# Marker Rotation (Euler angles in degrees): [-177.70282655  -53.11230146  -97.19395958]
# Marker Rotation (Euler angles in degrees): [-176.19245667  -53.00113898  -98.54641504]
# Marker Rotation (Euler angles in degrees): [-175.64701499  -52.74768725  -98.99739257]
# Marker Rotation (Euler angles in degrees): [-176.66575878  -53.67196052  -98.16560404]
# Marker Rotation (Euler angles in degrees): [-175.82117331  -52.96951266  -99.03604975]
# Marker Rotation (Euler angles in degrees): [-175.89656734  -52.53095669  -99.01049023]
# Marker Rotation (Euler angles in degrees): [-175.79767308  -52.95788414  -99.10731192]
# Marker Rotation (Euler angles in degrees): [-176.41650224  -52.79260427  -98.63461257]
# Marker Rotation (Euler angles in degrees): [-176.04016234  -52.75302983  -99.13490672]
# Marker Rotation (Euler angles in degrees): [-176.01955951  -52.75571962  -99.15180607]
# Marker Rotation (Euler angles in degrees): [-176.08022952  -53.41526329  -99.30463652]
# Marker Rotation (Euler angles in degrees): [-177.17265283  -53.93565619  -98.3822383 ]
# Marker Rotation (Euler angles in degrees): [-177.24778021  -53.51632262  -98.37034959]
# Marker Rotation (Euler angles in degrees): [-178.17037892  -53.8089209   -97.4612686 ]
# Marker Rotation (Euler angles in degrees): [-177.94124227  -54.01841638  -98.02964682]
# Marker Rotation (Euler angles in degrees): [-178.75110268  -54.08435648  -97.58202819]
# Marker Rotation (Euler angles in degrees): [-178.94421922  -54.32885749  -98.16291084]
# Marker Rotation (Euler angles in degrees): [-179.26831996  -55.45990749  -97.94350426]
# Marker Rotation (Euler angles in degrees): [-141.82221719  -82.54205122 -136.35964761]
# Marker Rotation (Euler angles in degrees): [-179.81356343  -55.74174908  -97.53198333]
# Marker Rotation (Euler angles in degrees): [-178.74757137  -56.51125762  -98.21250527]
# Marker Rotation (Euler angles in degrees): [-140.96414237  -82.74532357 -136.65191389]
# Marker Rotation (Euler angles in degrees): [-139.89296513  -82.94222738 -136.90433307]
# Marker Rotation (Euler angles in degrees): [173.90982826 -62.80682823 -89.94943423]
# Marker Rotation (Euler angles in degrees): [168.21528906 -65.44098235 -82.71080936]
# Marker Rotation (Euler angles in degrees): [-132.08949416  -83.75266935 -143.07425275]
# Marker Rotation (Euler angles in degrees): [-130.15214959  -83.81940872 -145.06253703]
# Marker Rotation (Euler angles in degrees): [-90.68072614 -44.25210242 -52.77223519]

# %% [markdown]
# para ver a rotação, é o ultimo angulo do array
